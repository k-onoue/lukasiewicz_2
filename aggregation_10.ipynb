# %% [markdown]
# あらゆる情報をまずは表にして，それから可視化する
#
# -

# %%
import json 
import pandas as pd

# %%
# data_dir_path = "/Users/keisukeonoue/ws/lukasiewicz_2/experiments"
result_file_path_list = [
    "./experiments/version_101/result.json",
    "./experiments/version_102/result.json",
    "./experiments/version_103/result.json",
    "./experiments/version_104/result.json",
    "./experiments/version_105/result.json",
    "./experiments/version_106/result.json",
]

result_file_path = result_file_path_list[0]

with open(result_file_path, 'r') as f:
    json_data = json.load(f)

json_data
# Out:
# {'path': './experiments/version_101',
#  'source_paths': ['data/pima_indian_diabetes/diabetes_cleaned_normalized.csv',
#   'data/pima_indian_diabetes/diabetes_discretized.csv'],
#  'experiment_name': 'pima_indian_diabetes_cv_10',
#  'seed': 42,
#  'n_splits': 5,
#  'n_unsupervised': 15,
#  'c1': 10,
#  'c2': 10,
#  'rule_thr': 0,
#  'result': {'fold_0': {'RuleFit Classifier (disc)': {'accuracy': 0.7761194029850746,
#     'precision': 0.7333333333333333,
#     'recall': 0.5,
#     'f1': 0.5945945945945945,
#     'auc': 0.8353535353535353,
#     'violation_detail': {'0': [79,
#       79,
#       [1,
#        3,
#        5,
#        6,
#        7,
#        9,
#        11,
#        13,
#        14,
#        21,
#        25,
#        26,
#        29,
#        32,
#        33,
#        37,
#        38,
#        40,
#        41,
#        45,
#        47,
#        48,
#        51,
#        54,
#        55,
#        56,
#        57,
#        58,
#        61,
#        62,
#        65,
#        66,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        76,
#        77,
#        79,
#        80,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        96,
#        99,
#        100,
#        102,
#        103,
#        104,
#        105,
#        106,
#        107,
#        108,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        118,
#        120,
#        122,
#        125,
#        126,
#        127,
#        129,
#        132,
#        133]],
#      '1': [31,
#       31,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        63,
#        64,
#        67,
#        73,
#        75,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        111,
#        115,
#        123,
#        125]],
#      '2': [26, 1, [83]],
#      '3': [61,
#       47,
#       [1,
#        3,
#        5,
#        13,
#        17,
#        18,
#        19,
#        28,
#        29,
#        38,
#        39,
#        42,
#        51,
#        53,
#        54,
#        57,
#        59,
#        62,
#        64,
#        65,
#        67,
#        68,
#        69,
#        71,
#        75,
#        78,
#        79,
#        81,
#        87,
#        88,
#        89,
#        90,
#        93,
#        99,
#        101,
#        102,
#        104,
#        105,
#        106,
#        111,
#        114,
#        115,
#        117,
#        119,
#        120,
#        123,
#        133]],
#      '4': [45,
#       45,
#       [1,
#        2,
#        3,
#        4,
#        10,
#        21,
#        22,
#        26,
#        27,
#        28,
#        29,
#        35,
#        36,
#        38,
#        40,
#        41,
#        42,
#        45,
#        50,
#        51,
#        56,
#        59,
#        65,
#        66,
#        68,
#        72,
#        73,
#        76,
#        77,
#        80,
#        81,
#        83,
#        84,
#        85,
#        87,
#        99,
#        100,
#        107,
#        112,
#        115,
#        118,
#        125,
#        127,
#        132,
#        133]],
#      '5': [84,
#       84,
#       [1,
#        3,
#        4,
#        5,
#        6,
#        7,
#        9,
#        12,
#        15,
#        17,
#        18,
#        19,
#        20,
#        22,
#        23,
#        26,
#        27,
#        30,
#        33,
#        35,
#        36,
#        39,
#        42,
#        45,
#        46,
#        48,
#        49,
#        52,
#        53,
#        56,
#        57,
#        59,
#        61,
#        62,
#        63,
#        64,
#        65,
#        66,
#        68,
#        70,
#        71,
#        72,
#        73,
#        74,
#        75,
#        76,
#        78,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        97,
#        99,
#        100,
#        101,
#        102,
#        103,
#        105,
#        106,
#        108,
#        110,
#        113,
#        117,
#        118,
#        119,
#        120,
#        121,
#        122,
#        123,
#        124,
#        125,
#        126,
#        127,
#        130,
#        131]],
#      '6': [88,
#       88,
#       [1,
#        2,
#        3,
#        4,
#        5,
#        7,
#        8,
#        11,
#        12,
#        13,
#        14,
#        17,
#        21,
#        25,
#        26,
#        27,
#        29,
#        30,
#        32,
#        33,
#        37,
#        38,
#        39,
#        40,
#        41,
#        42,
#        45,
#        47,
#        48,
#        50,
#        51,
#        53,
#        56,
#        57,
#        58,
#        59,
#        61,
#        62,
#        64,
#        65,
#        66,
#        67,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        77,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        89,
#        90,
#        91,
#        93,
#        94,
#        98,
#        99,
#        100,
#        101,
#        102,
#        103,
#        104,
#        105,
#        108,
#        109,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        117,
#        120,
#        122,
#        125,
#        126,
#        129,
#        131,
#        132,
#        133]],
#      '7': [35,
#       21,
#       [15,
#        18,
#        19,
#        23,
#        28,
#        35,
#        49,
#        52,
#        54,
#        63,
#        70,
#        75,
#        78,
#        88,
#        97,
#        106,
#        111,
#        119,
#        121,
#        123,
#        127]],
#      '8': [3, 0, []],
#      '9': [3, 0, []],
#      '10': [11, 11, [26, 45, 56, 66, 72, 73, 80, 85, 100, 125, 127]],
#      '11': [12, 12, [5, 57, 62, 71, 79, 89, 90, 93, 102, 105, 120, 126]],
#      '12': [27,
#       27,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        64,
#        67,
#        73,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        115,
#        125]],
#      '13': [19,
#       19,
#       [26,
#        27,
#        29,
#        35,
#        41,
#        45,
#        51,
#        66,
#        73,
#        80,
#        81,
#        83,
#        84,
#        87,
#        99,
#        107,
#        115,
#        132,
#        133]],
#      '14': [3, 1, [96]],
#      '15': [4, 2, [55, 119]],
#      '16': [1, 0, []],
#      '17': [1, 1, [78]],
#      '18': [3, 1, [119]],
#      '19': [3, 1, [119]],
#      '20': [3, 3, [15, 18, 23]],
#      '21': [5, 5, [66, 72, 84, 100, 127]],
#      '22': [4, 4, [22, 30, 70, 121]],
#      '23': [3, 3, [76, 118, 127]],
#      '24': [4, 4, [18, 19, 70, 121]],
#      '25': [2, 0, []],
#      '26': [12, 12, [21, 22, 40, 72, 76, 77, 84, 100, 107, 112, 118, 127]],
#      '27': [3, 3, [14, 37, 96]],
#      '28': [13, 13, [21, 29, 38, 40, 41, 51, 77, 87, 107, 112, 115, 132, 133]],
#      '29': [0, 0, []],
#      '30': [2, 0, []],
#      '31': [5, 5, [7, 15, 23, 61, 96]],
#      '32': [5, 0, []],
#      '33': [3, 3, [19, 70, 121]]},
#     'n_violation': 27,
#     'n_rule': 34,
#     'violation_rate': 0.7941176470588235,
#     'n_violation (instance)': 526,
#     'n_evaluation (instance)': 603,
#     'violation_rate (instance)': 0.8723051409618574},
#    'tree generator (disc)': {'accuracy': 0.7761194029850746,
#     'precision': 0.675,
#     'recall': 0.6136363636363636,
#     'f1': 0.6428571428571429,
#     'auc': 0.8170454545454545,
#     'violation_detail': {'0': [79,
#       79,
#       [1,
#        3,
#        5,
#        6,
#        7,
#        9,
#        11,
#        13,
#        14,
#        21,
#        25,
#        26,
#        29,
#        32,
#        33,
#        37,
#        38,
#        40,
#        41,
#        45,
#        47,
#        48,
#        51,
#        54,
#        55,
#        56,
#        57,
#        58,
#        61,
#        62,
#        65,
#        66,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        76,
#        77,
#        79,
#        80,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        96,
#        99,
#        100,
#        102,
#        103,
#        104,
#        105,
#        106,
#        107,
#        108,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        118,
#        120,
#        122,
#        125,
#        126,
#        127,
#        129,
#        132,
#        133]],
#      '1': [31,
#       31,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        63,
#        64,
#        67,
#        73,
#        75,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        111,
#        115,
#        123,
#        125]],
#      '2': [26, 5, [0, 6, 83, 92, 124]],
#      '3': [61,
#       45,
#       [0,
#        1,
#        3,
#        5,
#        13,
#        17,
#        18,
#        19,
#        28,
#        29,
#        38,
#        39,
#        42,
#        51,
#        53,
#        57,
#        59,
#        62,
#        64,
#        65,
#        67,
#        68,
#        69,
#        71,
#        75,
#        78,
#        79,
#        81,
#        87,
#        89,
#        90,
#        92,
#        93,
#        99,
#        101,
#        102,
#        104,
#        105,
#        111,
#        114,
#        115,
#        117,
#        120,
#        123,
#        133]],
#      '4': [45,
#       45,
#       [1,
#        2,
#        3,
#        4,
#        10,
#        21,
#        22,
#        26,
#        27,
#        28,
#        29,
#        35,
#        36,
#        38,
#        40,
#        41,
#        42,
#        45,
#        50,
#        51,
#        56,
#        59,
#        65,
#        66,
#        68,
#        72,
#        73,
#        76,
#        77,
#        80,
#        81,
#        83,
#        84,
#        85,
#        87,
#        99,
#        100,
#        107,
#        112,
#        115,
#        118,
#        125,
#        127,
#        132,
#        133]],
#      '5': [84,
#       84,
#       [1,
#        3,
#        4,
#        5,
#        6,
#        7,
#        9,
#        12,
#        15,
#        17,
#        18,
#        19,
#        20,
#        22,
#        23,
#        26,
#        27,
#        30,
#        33,
#        35,
#        36,
#        39,
#        42,
#        45,
#        46,
#        48,
#        49,
#        52,
#        53,
#        56,
#        57,
#        59,
#        61,
#        62,
#        63,
#        64,
#        65,
#        66,
#        68,
#        70,
#        71,
#        72,
#        73,
#        74,
#        75,
#        76,
#        78,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        97,
#        99,
#        100,
#        101,
#        102,
#        103,
#        105,
#        106,
#        108,
#        110,
#        113,
#        117,
#        118,
#        119,
#        120,
#        121,
#        122,
#        123,
#        124,
#        125,
#        126,
#        127,
#        130,
#        131]],
#      '6': [88,
#       88,
#       [1,
#        2,
#        3,
#        4,
#        5,
#        7,
#        8,
#        11,
#        12,
#        13,
#        14,
#        17,
#        21,
#        25,
#        26,
#        27,
#        29,
#        30,
#        32,
#        33,
#        37,
#        38,
#        39,
#        40,
#        41,
#        42,
#        45,
#        47,
#        48,
#        50,
#        51,
#        53,
#        56,
#        57,
#        58,
#        59,
#        61,
#        62,
#        64,
#        65,
#        66,
#        67,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        77,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        89,
#        90,
#        91,
#        93,
#        94,
#        98,
#        99,
#        100,
#        101,
#        102,
#        103,
#        104,
#        105,
#        108,
#        109,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        117,
#        120,
#        122,
#        125,
#        126,
#        129,
#        131,
#        132,
#        133]],
#      '7': [35,
#       16,
#       [0, 15, 18, 19, 23, 28, 35, 63, 70, 75, 78, 92, 111, 121, 123, 127]],
#      '8': [3, 0, []],
#      '9': [3, 0, []],
#      '10': [11, 11, [26, 45, 56, 66, 72, 73, 80, 85, 100, 125, 127]],
#      '11': [12, 12, [5, 57, 62, 71, 79, 89, 90, 93, 102, 105, 120, 126]],
#      '12': [27,
#       27,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        64,
#        67,
#        73,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        115,
#        125]],
#      '13': [19,
#       19,
#       [26,
#        27,
#        29,
#        35,
#        41,
#        45,
#        51,
#        66,
#        73,
#        80,
#        81,
#        83,
#        84,
#        87,
#        99,
#        107,
#        115,
#        132,
#        133]],
#      '14': [3, 0, []],
#      '15': [4, 0, []],
#      '16': [1, 0, []],
#      '17': [1, 1, [78]],
#      '18': [3, 0, []],
#      '19': [3, 0, []],
#      '20': [3, 3, [15, 18, 23]],
#      '21': [5, 5, [66, 72, 84, 100, 127]],
#      '22': [4, 4, [22, 30, 70, 121]],
#      '23': [3, 1, [127]],
#      '24': [4, 4, [18, 19, 70, 121]],
#      '25': [2, 0, []],
#      '26': [12, 12, [21, 22, 40, 72, 76, 77, 84, 100, 107, 112, 118, 127]],
#      '27': [3, 3, [14, 37, 96]],
#      '28': [13, 13, [21, 29, 38, 40, 41, 51, 77, 87, 107, 112, 115, 132, 133]],
#      '29': [0, 0, []],
#      '30': [2, 0, []],
#      '31': [5, 5, [7, 15, 23, 61, 96]],
#      '32': [5, 0, []],
#      '33': [3, 3, [19, 70, 121]]},
#     'n_violation': 23,
#     'n_rule': 34,
#     'violation_rate': 0.6764705882352942,
#     'n_violation (instance)': 516,
#     'n_evaluation (instance)': 603,
#     'violation_rate (instance)': 0.8557213930348259},
#    'RuleFit Classifier (conti)': {'accuracy': 0.7761194029850746,
#     'precision': 0.6842105263157895,
#     'recall': 0.5909090909090909,
#     'f1': 0.6341463414634148,
#     'auc': 0.8101010101010101,
#     'violation_detail': {'0': [79,
#       79,
#       [1,
#        3,
#        5,
#        6,
#        7,
#        9,
#        11,
#        13,
#        14,
#        21,
#        25,
#        26,
#        29,
#        32,
#        33,
#        37,
#        38,
#        40,
#        41,
#        45,
#        47,
#        48,
#        51,
#        54,
#        55,
#        56,
#        57,
#        58,
#        61,
#        62,
#        65,
#        66,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        76,
#        77,
#        79,
#        80,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        96,
#        99,
#        100,
#        102,
#        103,
#        104,
#        105,
#        106,
#        107,
#        108,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        118,
#        120,
#        122,
#        125,
#        126,
#        127,
#        129,
#        132,
#        133]],
#      '1': [31,
#       31,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        63,
#        64,
#        67,
#        73,
#        75,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        111,
#        115,
#        123,
#        125]],
#      '2': [26, 7, [0, 6, 83, 122, 124, 128, 129]],
#      '3': [61,
#       45,
#       [0,
#        1,
#        3,
#        5,
#        13,
#        18,
#        29,
#        38,
#        42,
#        51,
#        53,
#        54,
#        57,
#        62,
#        64,
#        65,
#        67,
#        68,
#        69,
#        71,
#        75,
#        78,
#        79,
#        81,
#        87,
#        88,
#        89,
#        90,
#        93,
#        99,
#        101,
#        102,
#        104,
#        105,
#        106,
#        111,
#        114,
#        115,
#        117,
#        119,
#        120,
#        122,
#        123,
#        128,
#        133]],
#      '4': [45,
#       45,
#       [1,
#        2,
#        3,
#        4,
#        10,
#        21,
#        22,
#        26,
#        27,
#        28,
#        29,
#        35,
#        36,
#        38,
#        40,
#        41,
#        42,
#        45,
#        50,
#        51,
#        56,
#        59,
#        65,
#        66,
#        68,
#        72,
#        73,
#        76,
#        77,
#        80,
#        81,
#        83,
#        84,
#        85,
#        87,
#        99,
#        100,
#        107,
#        112,
#        115,
#        118,
#        125,
#        127,
#        132,
#        133]],
#      '5': [84,
#       84,
#       [1,
#        3,
#        4,
#        5,
#        6,
#        7,
#        9,
#        12,
#        15,
#        17,
#        18,
#        19,
#        20,
#        22,
#        23,
#        26,
#        27,
#        30,
#        33,
#        35,
#        36,
#        39,
#        42,
#        45,
#        46,
#        48,
#        49,
#        52,
#        53,
#        56,
#        57,
#        59,
#        61,
#        62,
#        63,
#        64,
#        65,
#        66,
#        68,
#        70,
#        71,
#        72,
#        73,
#        74,
#        75,
#        76,
#        78,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        97,
#        99,
#        100,
#        101,
#        102,
#        103,
#        105,
#        106,
#        108,
#        110,
#        113,
#        117,
#        118,
#        119,
#        120,
#        121,
#        122,
#        123,
#        124,
#        125,
#        126,
#        127,
#        130,
#        131]],
#      '6': [88,
#       88,
#       [1,
#        2,
#        3,
#        4,
#        5,
#        7,
#        8,
#        11,
#        12,
#        13,
#        14,
#        17,
#        21,
#        25,
#        26,
#        27,
#        29,
#        30,
#        32,
#        33,
#        37,
#        38,
#        39,
#        40,
#        41,
#        42,
#        45,
#        47,
#        48,
#        50,
#        51,
#        53,
#        56,
#        57,
#        58,
#        59,
#        61,
#        62,
#        64,
#        65,
#        66,
#        67,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        77,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        89,
#        90,
#        91,
#        93,
#        94,
#        98,
#        99,
#        100,
#        101,
#        102,
#        103,
#        104,
#        105,
#        108,
#        109,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        117,
#        120,
#        122,
#        125,
#        126,
#        129,
#        131,
#        132,
#        133]],
#      '7': [35,
#       19,
#       [0,
#        15,
#        18,
#        23,
#        35,
#        49,
#        54,
#        63,
#        70,
#        75,
#        78,
#        88,
#        106,
#        111,
#        119,
#        121,
#        123,
#        127,
#        128]],
#      '8': [3, 1, [129]],
#      '9': [3, 0, []],
#      '10': [11, 11, [26, 45, 56, 66, 72, 73, 80, 85, 100, 125, 127]],
#      '11': [12, 12, [5, 57, 62, 71, 79, 89, 90, 93, 102, 105, 120, 126]],
#      '12': [27,
#       27,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        64,
#        67,
#        73,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        115,
#        125]],
#      '13': [19,
#       19,
#       [26,
#        27,
#        29,
#        35,
#        41,
#        45,
#        51,
#        66,
#        73,
#        80,
#        81,
#        83,
#        84,
#        87,
#        99,
#        107,
#        115,
#        132,
#        133]],
#      '14': [3, 0, []],
#      '15': [4, 1, [119]],
#      '16': [1, 0, []],
#      '17': [1, 1, [78]],
#      '18': [3, 1, [119]],
#      '19': [3, 1, [119]],
#      '20': [3, 3, [15, 18, 23]],
#      '21': [5, 5, [66, 72, 84, 100, 127]],
#      '22': [4, 4, [22, 30, 70, 121]],
#      '23': [3, 3, [76, 118, 127]],
#      '24': [4, 4, [18, 19, 70, 121]],
#      '25': [2, 1, [129]],
#      '26': [12, 12, [21, 22, 40, 72, 76, 77, 84, 100, 107, 112, 118, 127]],
#      '27': [3, 3, [14, 37, 96]],
#      '28': [13, 13, [21, 29, 38, 40, 41, 51, 77, 87, 107, 112, 115, 132, 133]],
#      '29': [0, 0, []],
#      '30': [2, 0, []],
#      '31': [5, 5, [7, 15, 23, 61, 96]],
#      '32': [5, 1, [128]],
#      '33': [3, 3, [19, 70, 121]]},
#     'n_violation': 29,
#     'n_rule': 34,
#     'violation_rate': 0.8529411764705882,
#     'n_violation (instance)': 529,
#     'n_evaluation (instance)': 603,
#     'violation_rate (instance)': 0.8772802653399668},
#    'tree generator (conti)': {'accuracy': 0.7761194029850746,
#     'precision': 0.6842105263157895,
#     'recall': 0.5909090909090909,
#     'f1': 0.6341463414634148,
#     'auc': 0.8347222222222223,
#     'violation_detail': {'0': [79,
#       79,
#       [1,
#        3,
#        5,
#        6,
#        7,
#        9,
#        11,
#        13,
#        14,
#        21,
#        25,
#        26,
#        29,
#        32,
#        33,
#        37,
#        38,
#        40,
#        41,
#        45,
#        47,
#        48,
#        51,
#        54,
#        55,
#        56,
#        57,
#        58,
#        61,
#        62,
#        65,
#        66,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        76,
#        77,
#        79,
#        80,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        96,
#        99,
#        100,
#        102,
#        103,
#        104,
#        105,
#        106,
#        107,
#        108,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        118,
#        120,
#        122,
#        125,
#        126,
#        127,
#        129,
#        132,
#        133]],
#      '1': [31,
#       31,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        63,
#        64,
#        67,
#        73,
#        75,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        111,
#        115,
#        123,
#        125]],
#      '2': [26, 4, [83, 122, 124, 129]],
#      '3': [61,
#       46,
#       [1,
#        3,
#        5,
#        13,
#        17,
#        18,
#        19,
#        29,
#        38,
#        39,
#        42,
#        51,
#        53,
#        54,
#        57,
#        62,
#        64,
#        65,
#        67,
#        68,
#        69,
#        71,
#        75,
#        78,
#        79,
#        81,
#        87,
#        88,
#        89,
#        90,
#        93,
#        99,
#        101,
#        102,
#        104,
#        105,
#        106,
#        111,
#        114,
#        115,
#        117,
#        119,
#        120,
#        122,
#        123,
#        133]],
#      '4': [45,
#       45,
#       [1,
#        2,
#        3,
#        4,
#        10,
#        21,
#        22,
#        26,
#        27,
#        28,
#        29,
#        35,
#        36,
#        38,
#        40,
#        41,
#        42,
#        45,
#        50,
#        51,
#        56,
#        59,
#        65,
#        66,
#        68,
#        72,
#        73,
#        76,
#        77,
#        80,
#        81,
#        83,
#        84,
#        85,
#        87,
#        99,
#        100,
#        107,
#        112,
#        115,
#        118,
#        125,
#        127,
#        132,
#        133]],
#      '5': [84,
#       84,
#       [1,
#        3,
#        4,
#        5,
#        6,
#        7,
#        9,
#        12,
#        15,
#        17,
#        18,
#        19,
#        20,
#        22,
#        23,
#        26,
#        27,
#        30,
#        33,
#        35,
#        36,
#        39,
#        42,
#        45,
#        46,
#        48,
#        49,
#        52,
#        53,
#        56,
#        57,
#        59,
#        61,
#        62,
#        63,
#        64,
#        65,
#        66,
#        68,
#        70,
#        71,
#        72,
#        73,
#        74,
#        75,
#        76,
#        78,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        97,
#        99,
#        100,
#        101,
#        102,
#        103,
#        105,
#        106,
#        108,
#        110,
#        113,
#        117,
#        118,
#        119,
#        120,
#        121,
#        122,
#        123,
#        124,
#        125,
#        126,
#        127,
#        130,
#        131]],
#      '6': [88,
#       88,
#       [1,
#        2,
#        3,
#        4,
#        5,
#        7,
#        8,
#        11,
#        12,
#        13,
#        14,
#        17,
#        21,
#        25,
#        26,
#        27,
#        29,
#        30,
#        32,
#        33,
#        37,
#        38,
#        39,
#        40,
#        41,
#        42,
#        45,
#        47,
#        48,
#        50,
#        51,
#        53,
#        56,
#        57,
#        58,
#        59,
#        61,
#        62,
#        64,
#        65,
#        66,
#        67,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        77,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        89,
#        90,
#        91,
#        93,
#        94,
#        98,
#        99,
#        100,
#        101,
#        102,
#        103,
#        104,
#        105,
#        108,
#        109,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        117,
#        120,
#        122,
#        125,
#        126,
#        129,
#        131,
#        132,
#        133]],
#      '7': [35,
#       19,
#       [15,
#        18,
#        19,
#        23,
#        35,
#        49,
#        54,
#        63,
#        70,
#        75,
#        78,
#        88,
#        97,
#        106,
#        111,
#        119,
#        121,
#        123,
#        127]],
#      '8': [3, 1, [129]],
#      '9': [3, 0, []],
#      '10': [11, 11, [26, 45, 56, 66, 72, 73, 80, 85, 100, 125, 127]],
#      '11': [12, 12, [5, 57, 62, 71, 79, 89, 90, 93, 102, 105, 120, 126]],
#      '12': [27,
#       27,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        64,
#        67,
#        73,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        115,
#        125]],
#      '13': [19,
#       19,
#       [26,
#        27,
#        29,
#        35,
#        41,
#        45,
#        51,
#        66,
#        73,
#        80,
#        81,
#        83,
#        84,
#        87,
#        99,
#        107,
#        115,
#        132,
#        133]],
#      '14': [3, 0, []],
#      '15': [4, 1, [119]],
#      '16': [1, 0, []],
#      '17': [1, 1, [78]],
#      '18': [3, 1, [119]],
#      '19': [3, 1, [119]],
#      '20': [3, 3, [15, 18, 23]],
#      '21': [5, 5, [66, 72, 84, 100, 127]],
#      '22': [4, 4, [22, 30, 70, 121]],
#      '23': [3, 3, [76, 118, 127]],
#      '24': [4, 4, [18, 19, 70, 121]],
#      '25': [2, 1, [129]],
#      '26': [12, 12, [21, 22, 40, 72, 76, 77, 84, 100, 107, 112, 118, 127]],
#      '27': [3, 3, [14, 37, 96]],
#      '28': [13, 13, [21, 29, 38, 40, 41, 51, 77, 87, 107, 112, 115, 132, 133]],
#      '29': [0, 0, []],
#      '30': [2, 0, []],
#      '31': [5, 5, [7, 15, 23, 61, 96]],
#      '32': [5, 0, []],
#      '33': [3, 3, [19, 70, 121]]},
#     'n_violation': 28,
#     'n_rule': 34,
#     'violation_rate': 0.8235294117647058,
#     'n_violation (instance)': 526,
#     'n_evaluation (instance)': 603,
#     'violation_rate (instance)': 0.8723051409618574},
#    'linear svm (L)': {'accuracy': 0.3283582089552239,
#     'precision': 0.3283582089552239,
#     'recall': 1.0,
#     'f1': 0.4943820224719101,
#     'auc': 0.21237373737373738,
#     'violation_detail': {'0': [79,
#       79,
#       [1,
#        3,
#        5,
#        6,
#        7,
#        9,
#        11,
#        13,
#        14,
#        21,
#        25,
#        26,
#        29,
#        32,
#        33,
#        37,
#        38,
#        40,
#        41,
#        45,
#        47,
#        48,
#        51,
#        54,
#        55,
#        56,
#        57,
#        58,
#        61,
#        62,
#        65,
#        66,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        76,
#        77,
#        79,
#        80,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        96,
#        99,
#        100,
#        102,
#        103,
#        104,
#        105,
#        106,
#        107,
#        108,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        118,
#        120,
#        122,
#        125,
#        126,
#        127,
#        129,
#        132,
#        133]],
#      '1': [31,
#       31,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        63,
#        64,
#        67,
#        73,
#        75,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        111,
#        115,
#        123,
#        125]],
#      '2': [26, 0, []],
#      '3': [61, 0, []],
#      '4': [45,
#       45,
#       [1,
#        2,
#        3,
#        4,
#        10,
#        21,
#        22,
#        26,
#        27,
#        28,
#        29,
#        35,
#        36,
#        38,
#        40,
#        41,
#        42,
#        45,
#        50,
#        51,
#        56,
#        59,
#        65,
#        66,
#        68,
#        72,
#        73,
#        76,
#        77,
#        80,
#        81,
#        83,
#        84,
#        85,
#        87,
#        99,
#        100,
#        107,
#        112,
#        115,
#        118,
#        125,
#        127,
#        132,
#        133]],
#      '5': [84,
#       84,
#       [1,
#        3,
#        4,
#        5,
#        6,
#        7,
#        9,
#        12,
#        15,
#        17,
#        18,
#        19,
#        20,
#        22,
#        23,
#        26,
#        27,
#        30,
#        33,
#        35,
#        36,
#        39,
#        42,
#        45,
#        46,
#        48,
#        49,
#        52,
#        53,
#        56,
#        57,
#        59,
#        61,
#        62,
#        63,
#        64,
#        65,
#        66,
#        68,
#        70,
#        71,
#        72,
#        73,
#        74,
#        75,
#        76,
#        78,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        97,
#        99,
#        100,
#        101,
#        102,
#        103,
#        105,
#        106,
#        108,
#        110,
#        113,
#        117,
#        118,
#        119,
#        120,
#        121,
#        122,
#        123,
#        124,
#        125,
#        126,
#        127,
#        130,
#        131]],
#      '6': [88,
#       88,
#       [1,
#        2,
#        3,
#        4,
#        5,
#        7,
#        8,
#        11,
#        12,
#        13,
#        14,
#        17,
#        21,
#        25,
#        26,
#        27,
#        29,
#        30,
#        32,
#        33,
#        37,
#        38,
#        39,
#        40,
#        41,
#        42,
#        45,
#        47,
#        48,
#        50,
#        51,
#        53,
#        56,
#        57,
#        58,
#        59,
#        61,
#        62,
#        64,
#        65,
#        66,
#        67,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        77,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        89,
#        90,
#        91,
#        93,
#        94,
#        98,
#        99,
#        100,
#        101,
#        102,
#        103,
#        104,
#        105,
#        108,
#        109,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        117,
#        120,
#        122,
#        125,
#        126,
#        129,
#        131,
#        132,
#        133]],
#      '7': [35, 0, []],
#      '8': [3, 0, []],
#      '9': [3, 0, []],
#      '10': [11, 11, [26, 45, 56, 66, 72, 73, 80, 85, 100, 125, 127]],
#      '11': [12, 12, [5, 57, 62, 71, 79, 89, 90, 93, 102, 105, 120, 126]],
#      '12': [27,
#       27,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        64,
#        67,
#        73,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        115,
#        125]],
#      '13': [19,
#       19,
#       [26,
#        27,
#        29,
#        35,
#        41,
#        45,
#        51,
#        66,
#        73,
#        80,
#        81,
#        83,
#        84,
#        87,
#        99,
#        107,
#        115,
#        132,
#        133]],
#      '14': [3, 0, []],
#      '15': [4, 0, []],
#      '16': [1, 0, []],
#      '17': [1, 1, [78]],
#      '18': [3, 0, []],
#      '19': [3, 0, []],
#      '20': [3, 3, [15, 18, 23]],
#      '21': [5, 5, [66, 72, 84, 100, 127]],
#      '22': [4, 4, [22, 30, 70, 121]],
#      '23': [3, 0, []],
#      '24': [4, 4, [18, 19, 70, 121]],
#      '25': [2, 0, []],
#      '26': [12, 12, [21, 22, 40, 72, 76, 77, 84, 100, 107, 112, 118, 127]],
#      '27': [3, 3, [14, 37, 96]],
#      '28': [13, 13, [21, 29, 38, 40, 41, 51, 77, 87, 107, 112, 115, 132, 133]],
#      '29': [0, 0, []],
#      '30': [2, 0, []],
#      '31': [5, 5, [7, 15, 23, 61, 96]],
#      '32': [5, 0, []],
#      '33': [3, 3, [19, 70, 121]]},
#     'n_violation': 19,
#     'n_rule': 34,
#     'violation_rate': 0.5588235294117647,
#     'n_violation (instance)': 449,
#     'n_evaluation (instance)': 603,
#     'violation_rate (instance)': 0.7446102819237148},
#    'non-linear svm (L)': {'accuracy': 0.6940298507462687,
#     'precision': 0.5263157894736842,
#     'recall': 0.6818181818181818,
#     'f1': 0.594059405940594,
#     'auc': 0.7835858585858585,
#     'violation_detail': {'0': [79,
#       24,
#       [6,
#        9,
#        11,
#        14,
#        25,
#        33,
#        37,
#        55,
#        57,
#        61,
#        77,
#        80,
#        82,
#        83,
#        88,
#        91,
#        96,
#        104,
#        108,
#        110,
#        116,
#        122,
#        126,
#        129]],
#      '1': [31, 2, [50, 80]],
#      '2': [26, 0, []],
#      '3': [61,
#       39,
#       [1,
#        3,
#        5,
#        13,
#        24,
#        29,
#        38,
#        39,
#        42,
#        51,
#        53,
#        54,
#        62,
#        64,
#        65,
#        67,
#        68,
#        69,
#        71,
#        75,
#        79,
#        81,
#        87,
#        89,
#        90,
#        93,
#        99,
#        101,
#        102,
#        105,
#        106,
#        111,
#        114,
#        115,
#        117,
#        119,
#        120,
#        123,
#        133]],
#      '4': [45, 10, [2, 10, 22, 28, 36, 50, 59, 77, 80, 83]],
#      '5': [84,
#       31,
#       [6,
#        9,
#        17,
#        18,
#        19,
#        20,
#        22,
#        23,
#        30,
#        33,
#        36,
#        46,
#        49,
#        57,
#        59,
#        61,
#        70,
#        78,
#        80,
#        82,
#        83,
#        88,
#        91,
#        97,
#        108,
#        110,
#        122,
#        124,
#        126,
#        130,
#        131]],
#      '6': [88,
#       27,
#       [2,
#        8,
#        11,
#        14,
#        17,
#        25,
#        30,
#        33,
#        37,
#        50,
#        57,
#        59,
#        61,
#        77,
#        80,
#        82,
#        83,
#        91,
#        104,
#        108,
#        109,
#        110,
#        116,
#        122,
#        126,
#        129,
#        131]],
#      '7': [35, 12, [15, 35, 52, 54, 63, 75, 106, 111, 119, 121, 123, 127]],
#      '8': [3, 0, []],
#      '9': [3, 0, []],
#      '10': [11, 1, [80]],
#      '11': [12, 2, [57, 126]],
#      '12': [27, 2, [50, 80]],
#      '13': [19, 2, [80, 83]],
#      '14': [3, 1, [24]],
#      '15': [4, 1, [119]],
#      '16': [1, 0, []],
#      '17': [1, 1, [78]],
#      '18': [3, 1, [119]],
#      '19': [3, 1, [119]],
#      '20': [3, 2, [18, 23]],
#      '21': [5, 0, []],
#      '22': [4, 3, [22, 30, 70]],
#      '23': [3, 3, [76, 118, 127]],
#      '24': [4, 3, [18, 19, 70]],
#      '25': [2, 0, []],
#      '26': [12, 2, [22, 77]],
#      '27': [3, 3, [14, 37, 96]],
#      '28': [13, 1, [77]],
#      '29': [0, 0, []],
#      '30': [2, 1, [24]],
#      '31': [5, 3, [23, 61, 96]],
#      '32': [5, 0, []],
#      '33': [3, 2, [19, 70]]},
#     'n_violation': 26,
#     'n_rule': 34,
#     'violation_rate': 0.7647058823529411,
#     'n_violation (instance)': 180,
#     'n_evaluation (instance)': 603,
#     'violation_rate (instance)': 0.29850746268656714},
#    'logistic regression (L)': {'accuracy': 0.7686567164179104,
#     'precision': 0.7096774193548387,
#     'recall': 0.5,
#     'f1': 0.5866666666666667,
#     'auc': 0.793939393939394,
#     'violation_detail': {'0': [79, 7, [6, 9, 25, 33, 91, 108, 110]],
#      '1': [31, 0, []],
#      '2': [26, 3, [83, 122, 129]],
#      '3': [61,
#       47,
#       [1,
#        3,
#        5,
#        13,
#        17,
#        19,
#        24,
#        29,
#        31,
#        38,
#        39,
#        42,
#        51,
#        53,
#        54,
#        57,
#        59,
#        62,
#        64,
#        65,
#        67,
#        68,
#        69,
#        71,
#        75,
#        79,
#        81,
#        87,
#        88,
#        89,
#        90,
#        93,
#        99,
#        101,
#        102,
#        104,
#        105,
#        106,
#        111,
#        114,
#        115,
#        117,
#        119,
#        120,
#        122,
#        123,
#        133]],
#      '4': [45, 5, [2, 10, 22, 28, 36]],
#      '5': [84,
#       17,
#       [6, 9, 18, 20, 22, 30, 33, 36, 46, 70, 78, 91, 108, 110, 124, 130, 131]],
#      '6': [88, 10, [2, 8, 25, 30, 33, 91, 108, 109, 110, 131]],
#      '7': [35,
#       19,
#       [15,
#        19,
#        23,
#        31,
#        34,
#        35,
#        49,
#        52,
#        54,
#        63,
#        75,
#        88,
#        97,
#        106,
#        111,
#        119,
#        121,
#        123,
#        127]],
#      '8': [3, 1, [129]],
#      '9': [3, 0, []],
#      '10': [11, 0, []],
#      '11': [12, 0, []],
#      '12': [27, 0, []],
#      '13': [19, 0, []],
#      '14': [3, 3, [24, 31, 96]],
#      '15': [4, 3, [34, 55, 119]],
#      '16': [1, 1, [31]],
#      '17': [1, 1, [78]],
#      '18': [3, 2, [34, 119]],
#      '19': [3, 2, [34, 119]],
#      '20': [3, 1, [18]],
#      '21': [5, 0, []],
#      '22': [4, 3, [22, 30, 70]],
#      '23': [3, 3, [76, 118, 127]],
#      '24': [4, 2, [18, 70]],
#      '25': [2, 1, [129]],
#      '26': [12, 1, [22]],
#      '27': [3, 0, []],
#      '28': [13, 0, []],
#      '29': [0, 0, []],
#      '30': [2, 2, [24, 31]],
#      '31': [5, 0, []],
#      '32': [5, 1, [31]],
#      '33': [3, 1, [70]]},
#     'n_violation': 23,
#     'n_rule': 34,
#     'violation_rate': 0.6764705882352942,
#     'n_violation (instance)': 136,
#     'n_evaluation (instance)': 603,
#     'violation_rate (instance)': 0.22553897180762852},
#    'linear svm': {'accuracy': 0.7686567164179104,
#     'precision': 0.696969696969697,
#     'recall': 0.5227272727272727,
#     'f1': 0.5974025974025974,
#     'auc': 0.8095959595959595,
#     'violation_detail': {'0': [79,
#       79,
#       [1,
#        3,
#        5,
#        6,
#        7,
#        9,
#        11,
#        13,
#        14,
#        21,
#        25,
#        26,
#        29,
#        32,
#        33,
#        37,
#        38,
#        40,
#        41,
#        45,
#        47,
#        48,
#        51,
#        54,
#        55,
#        56,
#        57,
#        58,
#        61,
#        62,
#        65,
#        66,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        76,
#        77,
#        79,
#        80,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        96,
#        99,
#        100,
#        102,
#        103,
#        104,
#        105,
#        106,
#        107,
#        108,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        118,
#        120,
#        122,
#        125,
#        126,
#        127,
#        129,
#        132,
#        133]],
#      '1': [31,
#       31,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        63,
#        64,
#        67,
#        73,
#        75,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        111,
#        115,
#        123,
#        125]],
#      '2': [26, 1, [83]],
#      '3': [61,
#       47,
#       [1,
#        3,
#        5,
#        13,
#        17,
#        19,
#        24,
#        28,
#        29,
#        31,
#        38,
#        39,
#        42,
#        51,
#        53,
#        54,
#        57,
#        59,
#        62,
#        64,
#        65,
#        67,
#        68,
#        69,
#        71,
#        75,
#        79,
#        81,
#        87,
#        88,
#        89,
#        90,
#        93,
#        99,
#        101,
#        102,
#        104,
#        105,
#        106,
#        111,
#        114,
#        115,
#        117,
#        119,
#        120,
#        123,
#        133]],
#      '4': [45,
#       45,
#       [1,
#        2,
#        3,
#        4,
#        10,
#        21,
#        22,
#        26,
#        27,
#        28,
#        29,
#        35,
#        36,
#        38,
#        40,
#        41,
#        42,
#        45,
#        50,
#        51,
#        56,
#        59,
#        65,
#        66,
#        68,
#        72,
#        73,
#        76,
#        77,
#        80,
#        81,
#        83,
#        84,
#        85,
#        87,
#        99,
#        100,
#        107,
#        112,
#        115,
#        118,
#        125,
#        127,
#        132,
#        133]],
#      '5': [84,
#       84,
#       [1,
#        3,
#        4,
#        5,
#        6,
#        7,
#        9,
#        12,
#        15,
#        17,
#        18,
#        19,
#        20,
#        22,
#        23,
#        26,
#        27,
#        30,
#        33,
#        35,
#        36,
#        39,
#        42,
#        45,
#        46,
#        48,
#        49,
#        52,
#        53,
#        56,
#        57,
#        59,
#        61,
#        62,
#        63,
#        64,
#        65,
#        66,
#        68,
#        70,
#        71,
#        72,
#        73,
#        74,
#        75,
#        76,
#        78,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        97,
#        99,
#        100,
#        101,
#        102,
#        103,
#        105,
#        106,
#        108,
#        110,
#        113,
#        117,
#        118,
#        119,
#        120,
#        121,
#        122,
#        123,
#        124,
#        125,
#        126,
#        127,
#        130,
#        131]],
#      '6': [88,
#       88,
#       [1,
#        2,
#        3,
#        4,
#        5,
#        7,
#        8,
#        11,
#        12,
#        13,
#        14,
#        17,
#        21,
#        25,
#        26,
#        27,
#        29,
#        30,
#        32,
#        33,
#        37,
#        38,
#        39,
#        40,
#        41,
#        42,
#        45,
#        47,
#        48,
#        50,
#        51,
#        53,
#        56,
#        57,
#        58,
#        59,
#        61,
#        62,
#        64,
#        65,
#        66,
#        67,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        77,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        89,
#        90,
#        91,
#        93,
#        94,
#        98,
#        99,
#        100,
#        101,
#        102,
#        103,
#        104,
#        105,
#        108,
#        109,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        117,
#        120,
#        122,
#        125,
#        126,
#        129,
#        131,
#        132,
#        133]],
#      '7': [35,
#       20,
#       [15,
#        19,
#        23,
#        28,
#        31,
#        35,
#        49,
#        52,
#        54,
#        63,
#        70,
#        75,
#        88,
#        97,
#        106,
#        111,
#        119,
#        121,
#        123,
#        127]],
#      '8': [3, 0, []],
#      '9': [3, 0, []],
#      '10': [11, 11, [26, 45, 56, 66, 72, 73, 80, 85, 100, 125, 127]],
#      '11': [12, 12, [5, 57, 62, 71, 79, 89, 90, 93, 102, 105, 120, 126]],
#      '12': [27,
#       27,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        64,
#        67,
#        73,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        115,
#        125]],
#      '13': [19,
#       19,
#       [26,
#        27,
#        29,
#        35,
#        41,
#        45,
#        51,
#        66,
#        73,
#        80,
#        81,
#        83,
#        84,
#        87,
#        99,
#        107,
#        115,
#        132,
#        133]],
#      '14': [3, 2, [24, 31]],
#      '15': [4, 2, [55, 119]],
#      '16': [1, 1, [31]],
#      '17': [1, 1, [78]],
#      '18': [3, 1, [119]],
#      '19': [3, 1, [119]],
#      '20': [3, 3, [15, 18, 23]],
#      '21': [5, 5, [66, 72, 84, 100, 127]],
#      '22': [4, 4, [22, 30, 70, 121]],
#      '23': [3, 3, [76, 118, 127]],
#      '24': [4, 4, [18, 19, 70, 121]],
#      '25': [2, 0, []],
#      '26': [12, 12, [21, 22, 40, 72, 76, 77, 84, 100, 107, 112, 118, 127]],
#      '27': [3, 3, [14, 37, 96]],
#      '28': [13, 13, [21, 29, 38, 40, 41, 51, 77, 87, 107, 112, 115, 132, 133]],
#      '29': [0, 0, []],
#      '30': [2, 2, [24, 31]],
#      '31': [5, 5, [7, 15, 23, 61, 96]],
#      '32': [5, 1, [31]],
#      '33': [3, 3, [19, 70, 121]]},
#     'n_violation': 30,
#     'n_rule': 34,
#     'violation_rate': 0.8823529411764706,
#     'n_violation (instance)': 530,
#     'n_evaluation (instance)': 603,
#     'violation_rate (instance)': 0.87893864013267},
#    'non-linear svm': {'accuracy': 0.8059701492537313,
#     'precision': 0.8214285714285714,
#     'recall': 0.5227272727272727,
#     'f1': 0.6388888888888888,
#     'auc': 0.8166666666666667,
#     'violation_detail': {'0': [79,
#       79,
#       [1,
#        3,
#        5,
#        6,
#        7,
#        9,
#        11,
#        13,
#        14,
#        21,
#        25,
#        26,
#        29,
#        32,
#        33,
#        37,
#        38,
#        40,
#        41,
#        45,
#        47,
#        48,
#        51,
#        54,
#        55,
#        56,
#        57,
#        58,
#        61,
#        62,
#        65,
#        66,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        76,
#        77,
#        79,
#        80,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        96,
#        99,
#        100,
#        102,
#        103,
#        104,
#        105,
#        106,
#        107,
#        108,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        118,
#        120,
#        122,
#        125,
#        126,
#        127,
#        129,
#        132,
#        133]],
#      '1': [31,
#       31,
#       [1,
#        3,
#        5,
#        26,
#        27,
#        32,
#        38,
#        42,
#        45,
#        50,
#        56,
#        62,
#        63,
#        64,
#        67,
#        73,
#        75,
#        79,
#        80,
#        81,
#        85,
#        86,
#        89,
#        90,
#        93,
#        94,
#        98,
#        111,
#        115,
#        123,
#        125]],
#      '2': [26, 4, [36, 83, 122, 124]],
#      '3': [61,
#       49,
#       [1,
#        3,
#        5,
#        13,
#        17,
#        19,
#        24,
#        28,
#        29,
#        31,
#        38,
#        39,
#        42,
#        51,
#        53,
#        54,
#        57,
#        59,
#        62,
#        64,
#        65,
#        67,
#        68,
#        69,
#        71,
#        75,
#        78,
#        79,
#        81,
#        87,
#        88,
#        89,
#        90,
#        93,
#        99,
#        101,
#        102,
#        104,
#        105,
#        106,
#        111,
#        114,
#        115,
#        117,
#        119,
#        120,
#        122,
#        123,
#        133]],
#      '4': [45,
#       45,
#       [1,
#        2,
#        3,
#        4,
#        10,
#        21,
#        22,
#        26,
#        27,
#        28,
#        29,
#        35,
#        36,
#        38,
#        40,
#        41,
#        42,
#        45,
#        50,
#        51,
#        56,
#        59,
#        65,
#        66,
#        68,
#        72,
#        73,
#        76,
#        77,
#        80,
#        81,
#        83,
#        84,
#        85,
#        87,
#        99,
#        100,
#        107,
#        112,
#        115,
#        118,
#        125,
#        127,
#        132,
#        133]],
#      '5': [84,
#       84,
#       [1,
#        3,
#        4,
#        5,
#        6,
#        7,
#        9,
#        12,
#        15,
#        17,
#        18,
#        19,
#        20,
#        22,
#        23,
#        26,
#        27,
#        30,
#        33,
#        35,
#        36,
#        39,
#        42,
#        45,
#        46,
#        48,
#        49,
#        52,
#        53,
#        56,
#        57,
#        59,
#        61,
#        62,
#        63,
#        64,
#        65,
#        66,
#        68,
#        70,
#        71,
#        72,
#        73,
#        74,
#        75,
#        76,
#        78,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        88,
#        89,
#        90,
#        91,
#        93,
#        94,
#        97,
#        99,
#        100,
#        101,
#        102,
#        103,
#        105,
#        106,
#        108,
#        110,
#        113,
#        117,
#        118,
#        119,
#        120,
#        121,
#        122,
#        123,
#        124,
#        125,
#        126,
#        127,
#        130,
#        131]],
#      '6': [88,
#       88,
#       [1,
#        2,
#        3,
#        4,
#        5,
#        7,
#        8,
#        11,
#        12,
#        13,
#        14,
#        17,
#        21,
#        25,
#        26,
#        27,
#        29,
#        30,
#        32,
#        33,
#        37,
#        38,
#        39,
#        40,
#        41,
#        42,
#        45,
#        47,
#        48,
#        50,
#        51,
#        53,
#        56,
#        57,
#        58,
#        59,
#        61,
#        62,
#        64,
#        65,
#        66,
#        67,
#        68,
#        69,
#        71,
#        72,
#        73,
#        74,
#        77,
#        79,
#        80,
#        81,
#        82,
#        83,
#        84,
#        85,
#        86,
#        87,
#        89,
#        90,
#        91,
#        93,
#        94,
#        98,
#        99,
#        100,
#        101,
#        102,
#        103,
#        104,
#        105,
#        108,
#        109,
#        110,
#        112,
#        113,
#        114,
#        115,
#        116,
#        117,
#        120,
#        122,
#        125,
#        126,
#        129,
#        131,
#        132,
#        133]],
#      '7': [35,
#       22,
#       [15,
#        19,
#        23,
#        28,
#        31,
#        35,
#        36,
#        49,
#        52,
#        54,
# ...
#        565,
#        568,
#        571,
#        576,
#        580,
#        583,
#        586,
#        587,
#        592,
#        593,
#        594,
#        596,
#        599,
#        605,
#        607,
#        615,
#        619,
#        630,
#        632,
#        633,
#        636,
#        638,
#        644,
#        651,
#        654,
#        662,
#        664,
#        667]],
#      '5': [92,
#       92,
#       [536,
#        537,
#        538,
#        539,
#        540,
#        541,
#        542,
#        544,
#        545,
#        546,
#        547,
#        549,
#        552,
#        554,
#        555,
#        557,
#        558,
#        560,
#        561,
#        562,
#        564,
#        566,
#        567,
#        568,
#        570,
#        571,
#        572,
#        574,
#        575,
#        576,
#        577,
#        578,
#        581,
#        582,
#        583,
#        584,
#        585,
#        587,
#        588,
#        589,
#        592,
#        593,
#        595,
#        598,
#        599,
#        600,
#        601,
#        607,
#        608,
#        609,
#        610,
#        612,
#        613,
#        614,
#        615,
#        616,
#        620,
#        621,
#        622,
#        623,
#        624,
#        625,
#        626,
#        627,
#        629,
#        630,
#        631,
#        632,
#        633,
#        635,
#        637,
#        641,
#        643,
#        644,
#        648,
#        650,
#        651,
#        653,
#        654,
#        655,
#        656,
#        658,
#        659,
#        660,
#        661,
#        663,
#        664,
#        665,
#        666,
#        667,
#        668,
#        669]],
#      '6': [87,
#       87,
#       [536,
#        537,
#        538,
#        539,
#        540,
#        542,
#        543,
#        544,
#        545,
#        546,
#        547,
#        550,
#        551,
#        552,
#        553,
#        554,
#        556,
#        557,
#        558,
#        559,
#        561,
#        562,
#        563,
#        564,
#        565,
#        566,
#        567,
#        568,
#        575,
#        580,
#        582,
#        584,
#        585,
#        586,
#        587,
#        588,
#        589,
#        590,
#        591,
#        592,
#        593,
#        594,
#        596,
#        597,
#        599,
#        601,
#        602,
#        603,
#        604,
#        607,
#        608,
#        609,
#        611,
#        612,
#        615,
#        616,
#        617,
#        618,
#        620,
#        622,
#        623,
#        628,
#        629,
#        630,
#        631,
#        632,
#        633,
#        634,
#        635,
#        637,
#        638,
#        640,
#        643,
#        644,
#        648,
#        649,
#        650,
#        652,
#        653,
#        654,
#        655,
#        660,
#        662,
#        664,
#        666,
#        667,
#        669]],
#      '7': [1, 1, [633]],
#      '8': [3, 3, [550, 611, 639]],
#      '9': [0, 0, []],
#      '10': [2, 2, [541, 549]],
#      '11': [3, 0, []],
#      '12': [3, 3, [550, 611, 639]],
#      '13': [10, 10, [563, 574, 577, 585, 609, 620, 635, 640, 643, 668]],
#      '14': [18,
#       18,
#       [536,
#        542,
#        547,
#        550,
#        562,
#        584,
#        587,
#        589,
#        599,
#        608,
#        611,
#        619,
#        631,
#        637,
#        649,
#        662,
#        664,
#        669]],
#      '15': [7, 7, [544, 566, 575, 623, 653, 666, 669]],
#      '16': [9, 9, [556, 565, 580, 586, 594, 603, 636, 649, 662]],
#      '17': [3, 3, [570, 626, 633]],
#      '18': [7, 3, [548, 647, 657]],
#      '19': [6, 3, [548, 647, 657]],
#      '20': [4, 2, [555, 624]],
#      '21': [7, 0, []],
#      '22': [3, 3, [600, 625, 633]],
#      '23': [3, 3, [541, 549, 555]],
#      '24': [7, 2, [581, 583]],
#      '25': [15,
#       15,
#       [545,
#        561,
#        562,
#        565,
#        568,
#        580,
#        586,
#        587,
#        593,
#        599,
#        615,
#        630,
#        638,
#        644,
#        662]],
#      '26': [6, 2, [548, 647]],
#      '27': [15,
#       15,
#       [539,
#        543,
#        545,
#        546,
#        552,
#        565,
#        580,
#        586,
#        592,
#        593,
#        596,
#        607,
#        615,
#        633,
#        644]],
#      '28': [2, 2, [541, 549]]},
#     'n_violation': 26,
#     'n_rule': 29,
#     'violation_rate': 0.896551724137931,
#     'n_violation (instance)': 461,
#     'n_evaluation (instance)': 518,
#     'violation_rate (instance)': 0.88996138996139},
#    'logistic regression': {'accuracy': 0.7761194029850746,
#     'precision': 0.7741935483870968,
#     'recall': 0.5106382978723404,
#     'f1': 0.6153846153846153,
#     'auc': 0.871851308388359,
#     'violation_detail': {'0': [87,
#       87,
#       [536,
#        537,
#        538,
#        539,
#        540,
#        542,
#        544,
#        545,
#        546,
#        550,
#        552,
#        553,
#        554,
#        556,
#        557,
#        558,
#        559,
#        561,
#        562,
#        563,
#        565,
#        566,
#        567,
#        568,
#        569,
#        575,
#        580,
#        584,
#        585,
#        586,
#        587,
#        588,
#        589,
#        590,
#        591,
#        592,
#        593,
#        594,
#        595,
#        597,
#        599,
#        601,
#        602,
#        603,
#        604,
#        606,
#        607,
#        609,
#        611,
#        612,
#        615,
#        616,
#        618,
#        620,
#        622,
#        623,
#        624,
#        626,
#        627,
#        628,
#        629,
#        630,
#        631,
#        632,
#        634,
#        635,
#        636,
#        637,
#        638,
#        640,
#        641,
#        643,
#        644,
#        648,
#        649,
#        650,
#        652,
#        653,
#        654,
#        655,
#        657,
#        659,
#        660,
#        662,
#        666,
#        668,
#        669]],
#      '1': [22,
#       22,
#       [536,
#        538,
#        542,
#        547,
#        550,
#        562,
#        581,
#        584,
#        587,
#        589,
#        599,
#        608,
#        611,
#        619,
#        622,
#        631,
#        637,
#        639,
#        649,
#        662,
#        664,
#        669]],
#      '2': [29, 9, [555, 557, 558, 567, 601, 612, 624, 630, 651]],
#      '3': [27,
#       15,
#       [538,
#        553,
#        560,
#        581,
#        600,
#        602,
#        622,
#        625,
#        626,
#        629,
#        630,
#        633,
#        638,
#        647,
#        658]],
#      '4': [40,
#       40,
#       [539,
#        542,
#        543,
#        545,
#        546,
#        547,
#        552,
#        556,
#        558,
#        560,
#        561,
#        562,
#        565,
#        568,
#        571,
#        576,
#        580,
#        583,
#        586,
#        587,
#        592,
#        593,
#        594,
#        596,
#        599,
#        605,
#        607,
#        615,
#        619,
#        630,
#        632,
#        633,
#        636,
#        638,
#        644,
#        651,
#        654,
#        662,
#        664,
#        667]],
#      '5': [92,
#       92,
#       [536,
#        537,
#        538,
#        539,
#        540,
#        541,
#        542,
#        544,
#        545,
#        546,
#        547,
#        549,
#        552,
#        554,
#        555,
#        557,
#        558,
#        560,
#        561,
#        562,
#        564,
#        566,
#        567,
#        568,
#        570,
#        571,
#        572,
#        574,
#        575,
#        576,
#        577,
#        578,
#        581,
#        582,
#        583,
#        584,
#        585,
#        587,
#        588,
#        589,
#        592,
#        593,
#        595,
#        598,
#        599,
#        600,
#        601,
#        607,
#        608,
#        609,
#        610,
#        612,
#        613,
#        614,
#        615,
#        616,
#        620,
#        621,
#        622,
#        623,
#        624,
#        625,
#        626,
#        627,
#        629,
#        630,
#        631,
#        632,
#        633,
#        635,
#        637,
#        641,
#        643,
#        644,
#        648,
#        650,
#        651,
#        653,
#        654,
#        655,
#        656,
#        658,
#        659,
#        660,
#        661,
#        663,
#        664,
#        665,
#        666,
#        667,
#        668,
#        669]],
#      '6': [87,
#       87,
#       [536,
#        537,
#        538,
#        539,
#        540,
#        542,
#        543,
#        544,
#        545,
#        546,
#        547,
#        550,
#        551,
#        552,
#        553,
#        554,
#        556,
#        557,
#        558,
#        559,
#        561,
#        562,
#        563,
#        564,
#        565,
#        566,
#        567,
#        568,
#        575,
#        580,
#        582,
#        584,
#        585,
#        586,
#        587,
#        588,
#        589,
#        590,
#        591,
#        592,
#        593,
#        594,
#        596,
#        597,
#        599,
#        601,
#        602,
#        603,
#        604,
#        607,
#        608,
#        609,
#        611,
#        612,
#        615,
#        616,
#        617,
#        618,
#        620,
#        622,
#        623,
#        628,
#        629,
#        630,
#        631,
#        632,
#        633,
#        634,
#        635,
#        637,
#        638,
#        640,
#        643,
#        644,
#        648,
#        649,
#        650,
#        652,
#        653,
#        654,
#        655,
#        660,
#        662,
#        664,
#        666,
#        667,
#        669]],
#      '7': [1, 1, [633]],
#      '8': [3, 3, [550, 611, 639]],
#      '9': [0, 0, []],
#      '10': [2, 2, [541, 549]],
#      '11': [3, 0, []],
#      '12': [3, 3, [550, 611, 639]],
#      '13': [10, 10, [563, 574, 577, 585, 609, 620, 635, 640, 643, 668]],
#      '14': [18,
#       18,
#       [536,
#        542,
#        547,
#        550,
#        562,
#        584,
#        587,
#        589,
#        599,
#        608,
#        611,
#        619,
#        631,
#        637,
#        649,
#        662,
#        664,
#        669]],
#      '15': [7, 7, [544, 566, 575, 623, 653, 666, 669]],
#      '16': [9, 9, [556, 565, 580, 586, 594, 603, 636, 649, 662]],
#      '17': [3, 3, [570, 626, 633]],
#      '18': [7, 2, [548, 647]],
#      '19': [6, 2, [548, 647]],
#      '20': [4, 2, [555, 624]],
#      '21': [7, 0, []],
#      '22': [3, 3, [600, 625, 633]],
#      '23': [3, 3, [541, 549, 555]],
#      '24': [7, 1, [581]],
#      '25': [15,
#       15,
#       [545,
#        561,
#        562,
#        565,
#        568,
#        580,
#        586,
#        587,
#        593,
#        599,
#        615,
#        630,
#        638,
#        644,
#        662]],
#      '26': [6, 2, [548, 647]],
#      '27': [15,
#       15,
#       [539,
#        543,
#        545,
#        546,
#        552,
#        565,
#        580,
#        586,
#        592,
#        593,
#        596,
#        607,
#        615,
#        633,
#        644]],
#      '28': [2, 2, [541, 549]]},
#     'n_violation': 26,
#     'n_rule': 29,
#     'violation_rate': 0.896551724137931,
#     'n_violation (instance)': 455,
#     'n_evaluation (instance)': 518,
#     'violation_rate (instance)': 0.8783783783783784},
#    'rule_based_prediction': {'accuracy': 0.35074626865671643,
#     'precision': 0.35074626865671643,
#     'recall': 1.0,
#     'f1': 0.5193370165745856,
#     'auc': 0.5,
#     'violation_detail': {'0': [87,
#       87,
#       [536,
#        537,
#        538,
#        539,
#        540,
#        542,
#        544,
#        545,
#        546,
#        550,
#        552,
#        553,
#        554,
#        556,
#        557,
#        558,
#        559,
#        561,
#        562,
#        563,
#        565,
#        566,
#        567,
#        568,
#        569,
#        575,
#        580,
#        584,
#        585,
#        586,
#        587,
#        588,
#        589,
#        590,
#        591,
#        592,
#        593,
#        594,
#        595,
#        597,
#        599,
#        601,
#        602,
#        603,
#        604,
#        606,
#        607,
#        609,
#        611,
#        612,
#        615,
#        616,
#        618,
#        620,
#        622,
#        623,
#        624,
#        626,
#        627,
#        628,
#        629,
#        630,
#        631,
#        632,
#        634,
#        635,
#        636,
#        637,
#        638,
#        640,
#        641,
#        643,
#        644,
#        648,
#        649,
#        650,
#        652,
#        653,
#        654,
#        655,
#        657,
#        659,
#        660,
#        662,
#        666,
#        668,
#        669]],
#      '1': [22,
#       22,
#       [536,
#        538,
#        542,
#        547,
#        550,
#        562,
#        581,
#        584,
#        587,
#        589,
#        599,
#        608,
#        611,
#        619,
#        622,
#        631,
#        637,
#        639,
#        649,
#        662,
#        664,
#        669]],
#      '2': [29, 0, []],
#      '3': [27, 0, []],
#      '4': [40,
#       40,
#       [539,
#        542,
#        543,
#        545,
#        546,
#        547,
#        552,
#        556,
#        558,
#        560,
#        561,
#        562,
#        565,
#        568,
#        571,
#        576,
#        580,
#        583,
#        586,
#        587,
#        592,
#        593,
#        594,
#        596,
#        599,
#        605,
#        607,
#        615,
#        619,
#        630,
#        632,
#        633,
#        636,
#        638,
#        644,
#        651,
#        654,
#        662,
#        664,
#        667]],
#      '5': [92,
#       92,
#       [536,
#        537,
#        538,
#        539,
#        540,
#        541,
#        542,
#        544,
#        545,
#        546,
#        547,
#        549,
#        552,
#        554,
#        555,
#        557,
#        558,
#        560,
#        561,
#        562,
#        564,
#        566,
#        567,
#        568,
#        570,
#        571,
#        572,
#        574,
#        575,
#        576,
#        577,
#        578,
#        581,
#        582,
#        583,
#        584,
#        585,
#        587,
#        588,
#        589,
#        592,
#        593,
#        595,
#        598,
#        599,
#        600,
#        601,
#        607,
#        608,
#        609,
#        610,
#        612,
#        613,
#        614,
#        615,
#        616,
#        620,
#        621,
#        622,
#        623,
#        624,
#        625,
#        626,
#        627,
#        629,
#        630,
#        631,
#        632,
#        633,
#        635,
#        637,
#        641,
#        643,
#        644,
#        648,
#        650,
#        651,
#        653,
#        654,
#        655,
#        656,
#        658,
#        659,
#        660,
#        661,
#        663,
#        664,
#        665,
#        666,
#        667,
#        668,
#        669]],
#      '6': [87,
#       87,
#       [536,
#        537,
#        538,
#        539,
#        540,
#        542,
#        543,
#        544,
#        545,
#        546,
#        547,
#        550,
#        551,
#        552,
#        553,
#        554,
#        556,
#        557,
#        558,
#        559,
#        561,
#        562,
#        563,
#        564,
#        565,
#        566,
#        567,
#        568,
#        575,
#        580,
#        582,
#        584,
#        585,
#        586,
#        587,
#        588,
#        589,
#        590,
#        591,
#        592,
#        593,
#        594,
#        596,
#        597,
#        599,
#        601,
#        602,
#        603,
#        604,
#        607,
#        608,
#        609,
#        611,
#        612,
#        615,
#        616,
#        617,
#        618,
#        620,
#        622,
#        623,
#        628,
#        629,
#        630,
#        631,
#        632,
#        633,
#        634,
#        635,
#        637,
#        638,
#        640,
#        643,
#        644,
#        648,
#        649,
#        650,
#        652,
#        653,
#        654,
#        655,
#        660,
#        662,
#        664,
#        666,
#        667,
#        669]],
#      '7': [1, 1, [633]],
#      '8': [3, 3, [550, 611, 639]],
#      '9': [0, 0, []],
#      '10': [2, 0, []],
#      '11': [3, 0, []],
#      '12': [3, 3, [550, 611, 639]],
#      '13': [10, 10, [563, 574, 577, 585, 609, 620, 635, 640, 643, 668]],
#      '14': [18,
#       18,
#       [536,
#        542,
#        547,
#        550,
#        562,
#        584,
#        587,
#        589,
#        599,
#        608,
#        611,
#        619,
#        631,
#        637,
#        649,
#        662,
#        664,
#        669]],
#      '15': [7, 7, [544, 566, 575, 623, 653, 666, 669]],
#      '16': [9, 9, [556, 565, 580, 586, 594, 603, 636, 649, 662]],
#      '17': [3, 3, [570, 626, 633]],
#      '18': [7, 0, []],
#      '19': [6, 0, []],
#      '20': [4, 0, []],
#      '21': [7, 0, []],
#      '22': [3, 3, [600, 625, 633]],
#      '23': [3, 0, []],
#      '24': [7, 0, []],
#      '25': [15,
#       15,
#       [545,
#        561,
#        562,
#        565,
#        568,
#        580,
#        586,
#        587,
#        593,
#        599,
#        615,
#        630,
#        638,
#        644,
#        662]],
#      '26': [6, 0, []],
#      '27': [15,
#       15,
#       [539,
#        543,
#        545,
#        546,
#        552,
#        565,
#        580,
#        586,
#        592,
#        593,
#        596,
#        607,
#        615,
#        633,
#        644]],
#      '28': [2, 0, []]},
#     'n_violation': 16,
#     'n_rule': 29,
#     'violation_rate': 0.5517241379310345,
#     'n_violation (instance)': 415,
#     'n_evaluation (instance)': 518,
#     'violation_rate (instance)': 0.8011583011583011}}}}
