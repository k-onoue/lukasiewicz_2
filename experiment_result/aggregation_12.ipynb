# %% [markdown]
# ## 一時保存した実験結果の読み込み

# %%
import json
import os

import sys
project_dir_path = "/Users/keisukeonoue/ws/lukasiewicz_2"
sys.path.append(project_dir_path)

import pandas as pd
import numpy as np

version_nums = [121, 122, 123, 124, 125, 126, 127]
expt_num = 12
expt_info_main = "c2"

# リスト内包表記を使用して複数のファイルパスを生成する
result_file_paths = [
    os.path.join(project_dir_path, f"experiment_result/tmp/version_{version_num}/result.json")
    for version_num in version_nums
]


result_dfs = []
infos = []

for path in result_file_paths:
    with open(path, 'r') as f:
        json_data = json.load(f)
    
    infos.append(json_data[expt_info_main])
    
    tmp = []

    for fold, _ in json_data['result'].items():
        result_df = pd.DataFrame(json_data['result'][fold]).T.drop(['violation_detail'], axis=1)
        tmp.append(result_df)

    result_dfs.append(tmp)

model_name_dict = {
    'linear svm': 'l-SVM', 
    'non-linear svm': 'r-SVM', 
    'logistic regression': 'RogReg', 
    'RuleFit Classifier (disc)': 'RuleFit-d', 
    'RuleFit Classifier (conti)': 'RuleFit', 
    'tree generator (disc)': 'RF-d', 
    'tree generator (conti)': 'RF', 
    'linear svm (L)': 'l-SVM-p', 
    'non-linear svm (L)': 'r-SVM-p', 
    'logistic regression (L)': 'LogReg-p', 
    'rule_based_prediction': 'RuleBase'
}

model_name_list = list(model_name_dict.keys())

combined_dfs = [pd.concat(dfs, ignore_index=False) for dfs in result_dfs]
dfs_mean = [combined_df.groupby(combined_df.index).mean().reindex(index=model_name_list) for combined_df in combined_dfs]
dfs_std = [combined_df.groupby(combined_df.index).std().reindex(index=model_name_list) for combined_df in combined_dfs]

for df in dfs_mean:
    display(df)
# Out:
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816319
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.447761  0.386567  0.930519  0.532321  0.508181
# non-linear svm (L)          0.737313  0.570807  0.771715  0.655025  0.827639
# logistic regression (L)     0.767164  0.710831  0.496076  0.579919  0.823544
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     1.8    3.0           0.54
# non-linear svm (L)                 0.8    3.0           0.16
# logistic regression (L)            2.2    3.0           0.72
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               25.4                    68.8
# non-linear svm (L)                            5.2                    68.8
# logistic regression (L)                       8.2                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.319946
# non-linear svm (L)                          0.050299
# logistic regression (L)                     0.120951
# rule_based_prediction                            NaN
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816319
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)               0.39403  0.362777  0.952174  0.511956  0.423113
# non-linear svm (L)          0.692537  0.525985  0.781676  0.619154   0.82768
# logistic regression (L)     0.767164  0.710831  0.496076  0.579919  0.823544
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     1.6    3.0            0.6
# non-linear svm (L)                 1.4    3.0            0.4
# logistic regression (L)            2.2    3.0           0.72
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               38.0                    68.8
# non-linear svm (L)                            7.6                    68.8
# logistic regression (L)                       8.2                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.480953
# non-linear svm (L)                          0.089997
# logistic regression (L)                     0.120951
# rule_based_prediction                            NaN
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816319
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.402985  0.375947  0.934783  0.513487  0.537018
# non-linear svm (L)          0.708955  0.541063  0.770265  0.629297  0.826676
# logistic regression (L)     0.767164  0.710831  0.496076  0.579919  0.823937
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     1.6    3.0            0.6
# non-linear svm (L)                 1.2    3.0           0.36
# logistic regression (L)            2.2    3.0           0.72
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               38.2                    68.8
# non-linear svm (L)                            6.2                    68.8
# logistic regression (L)                       8.2                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                               0.48836
# non-linear svm (L)                          0.070542
# logistic regression (L)                     0.120951
# rule_based_prediction                            NaN
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816319
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.462687   0.39847  0.911412  0.536208  0.513341
# non-linear svm (L)          0.701493  0.531045  0.776515  0.624731  0.825918
# logistic regression (L)     0.768657  0.716496  0.496076  0.581533  0.825475
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     1.8    3.0           0.54
# non-linear svm (L)                 1.4    3.0            0.4
# logistic regression (L)            2.0    3.0           0.68
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               25.0                    68.8
# non-linear svm (L)                            7.0                    68.8
# logistic regression (L)                       8.0                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.310844
# non-linear svm (L)                          0.078542
# logistic regression (L)                     0.118951
# rule_based_prediction                            NaN
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816319
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.680597  0.513395  0.724603  0.592933  0.778884
# non-linear svm (L)          0.729851  0.561317  0.769003  0.646187  0.820316
# logistic regression (L)     0.765672  0.719875  0.481396  0.569155  0.828173
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     2.6    3.0           0.92
# non-linear svm (L)                 1.4    3.0            0.4
# logistic regression (L)            2.0    3.0           0.68
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               12.0                    68.8
# non-linear svm (L)                            7.4                    68.8
# logistic regression (L)                       8.6                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.158731
# non-linear svm (L)                          0.078602
# logistic regression (L)                     0.122654
# rule_based_prediction                            NaN
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816319
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.597015  0.451998  0.817129  0.573372  0.670032
# non-linear svm (L)          0.713433  0.555363  0.715896    0.6125  0.818646
# logistic regression (L)     0.761194  0.709392  0.470891   0.55922  0.828583
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     2.4    3.0           0.72
# non-linear svm (L)                 2.4    3.0           0.82
# logistic regression (L)            2.2    3.0           0.72
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               14.6                    68.8
# non-linear svm (L)                            7.6                    68.8
# logistic regression (L)                       9.0                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.183183
# non-linear svm (L)                          0.093366
# logistic regression (L)                     0.126654
# rule_based_prediction                            NaN
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816319
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.544776  0.428728  0.918058  0.576362  0.794544
# non-linear svm (L)          0.670149  0.505928  0.770404   0.59874  0.785339
# logistic regression (L)     0.762687  0.717924  0.466809  0.557771  0.829222
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     1.8    3.0            0.7
# non-linear svm (L)                 2.0    3.0           0.58
# logistic regression (L)            2.0    3.0           0.68
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               29.0                    68.8
# non-linear svm (L)                            9.6                    68.8
# logistic regression (L)                       9.4                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.320601
# non-linear svm (L)                          0.121222
# logistic regression (L)                     0.130261
# rule_based_prediction                            NaN

# %% [markdown]
# ## 実験結果の保存（クロスバリデーション）

# %%
import os
# 実験によってパラメータが違うので注意
######################################
######################################
######################################
######################################


for version, (dfs, info) in enumerate(zip(result_dfs, infos)):
    
    for nth_fold, df in enumerate(dfs):

        df['nth_fold'] = nth_fold
        df['n_splits'] = 5
        df['C1'] = 10
        df['C2'] = info
        df['n_unsupervised'] = 15
        df['rule_thr'] = 0.8

        # フォルダーを作成する
        ########################################
        ########################################
        ########################################
        ########################################
        ########################################
        folder_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/fold_{nth_fold}')
        os.makedirs(folder_path, exist_ok=True)

        file_path = f'{folder_path}/ver_{version}.csv'
        print(file_path)

        df.to_csv(file_path)
# Out:
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_0/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_1/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_2/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_3/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_4/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_0/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_1/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_2/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_3/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_4/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_0/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_1/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_2/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_3/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_4/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_0/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_1/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_2/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_3/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_4/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_0/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_1/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_2/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_3/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_4/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_0/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_1/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_2/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_3/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_4/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_0/ver_6.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_1/ver_6.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_2/ver_6.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_3/ver_6.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/fold_4/ver_6.csv

# %% [markdown]
# ## 実験結果の保存（クロスバリデーション，平均と標準偏差）

# %%
# 実験によってパラメータが違うので注意
######################################
######################################
######################################
######################################


for version, (info, df) in enumerate(zip(infos, dfs_mean)):
    df['C1'] = 10
    df['C2'] = info
    df['n_unsupervised'] = 15
    df['rule_thr'] = 0.8

    #####################################
    #####################################
    #####################################
    #####################################
    #####################################
    file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/ver_{version}_mean.csv')
    print(file_path)

    df.to_csv(file_path)

for version, (info, df) in enumerate(zip(infos, dfs_std)):
    df['C1'] = 10
    df['C2'] = info
    df['n_unsupervised'] = 15
    df['rule_thr'] = 0.8

    #####################################
    #####################################
    #####################################
    #####################################
    #####################################
    file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/ver_{version}_std.csv')
    print(file_path)

    df.to_csv(file_path)
# Out:
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_0_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_1_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_2_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_3_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_4_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_5_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_6_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_0_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_1_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_2_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_3_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_4_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_5_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_12/ver_6_std.csv

# %% [markdown]
# ## ルールの整形と保存（csv）
#
# experiment_11, experiment_12, experiment_13，experiment_14 は無し．

# %%
# for nth_fold in range(5):
#     for version in range(len(infos)):

#         ###################################################
#         ###################################################
#         ###################################################
#         ###################################################
#         dir_path = os.path.join(project_dir_path, f"experiment_result/tmp/version_{expt_num}{version + 1}")

#         file_path_1 = f"{dir_path}/rules/rules_{nth_fold}.csv"
#         file_path_2 = f"{dir_path}/rules/rules_{nth_fold}.txt"
#         file_path_3 = f"{dir_path}/result.json"

#         with open(file_path_3, 'r') as f:
#             result = json.load(f)
#         rule_result = result['result'][f'fold_{nth_fold}']['rule_based_prediction']['violation_detail']
#         df_rule_result = pd.DataFrame(rule_result).T

        
#         df = pd.read_csv(file_path_1, index_col=0)

#         KB = []
#         with open(file_path_2, 'r') as f:
#             for line in f:
#                 KB.append(line.rstrip())

#         df.drop(['type', 'support', 'importance'], axis=1, inplace=True)
#         df['rule'] = KB[:df.shape[0]]

#         n_predicate_list = [] 
#         implication_bool_list = []
#         for h, rule in enumerate(df['rule']):
#             n_predicate_list.append(sum([1 for element in rule.split() if element not in ['⊗', '¬', '→']]))

#             # consequent カラムのために後で追加
#             if rule[rule.split().index('→') + 1] == '¬':
#                 implication_bool_list.append('¬')
#             else:
#                 implication_bool_list.append(None)

#         df['n_predicate'] = n_predicate_list
#         df['rank'] = df['coef'].apply(lambda x: sum(abs(x) > info for info in infos) - 1)


#         df['n_violation (instance)'] = df_rule_result[1].to_list()
#         df['n_evaluation (instance)'] = df_rule_result[0].to_list()
#         df['violation'] = df['n_violation (instance)'].apply(lambda x: 0 if x == 0 else 1)
#         df['consequent'] = implication_bool_list

#         display(df.head(3))
#         ########################################################
#         ########################################################
#         ########################################################
#         ########################################################
#         file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/fold_{nth_fold}/rules_{version}.csv')
#         df.to_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 16
#      14 with open(file_path_3, 'r') as f:
#      15     result = json.load(f)
# ---> 16 rule_result = result['result'][f'fold_{nth_fold}']['rule_based_prediction']['violation_detail']
#      17 df_rule_result = pd.DataFrame(rule_result).T
#      20 df = pd.read_csv(file_path_1, index_col=0)
#
# KeyError: 'rule_based_prediction'
