# %% [markdown]
# ## 一時保存した実験結果の読み込み

# %%
import json
import os

import sys
project_dir_path = "/Users/keisukeonoue/ws/lukasiewicz_2"
sys.path.append(project_dir_path)

import pandas as pd
import numpy as np

version_nums = [141, 142, 143, 144, 145]
expt_num = 14
expt_info_main = "n_unsupervised"

# リスト内包表記を使用して複数のファイルパスを生成する
result_file_paths = [
    os.path.join(project_dir_path, f"experiment_result/tmp/version_{version_num}/result.json")
    for version_num in version_nums
]


result_dfs = []
infos = []

for path in result_file_paths:
    with open(path, 'r') as f:
        json_data = json.load(f)
    
    infos.append(json_data[expt_info_main])
    
    tmp = []

    for fold, _ in json_data['result'].items():
        result_df = pd.DataFrame(json_data['result'][fold]).T.drop(['violation_detail'], axis=1)
        tmp.append(result_df)

    result_dfs.append(tmp)

model_name_dict = {
    'linear svm': 'l-SVM', 
    'non-linear svm': 'r-SVM', 
    'logistic regression': 'RogReg', 
    'RuleFit Classifier (disc)': 'RuleFit-d', 
    'RuleFit Classifier (conti)': 'RuleFit', 
    'tree generator (disc)': 'RF-d', 
    'tree generator (conti)': 'RF', 
    'linear svm (L)': 'l-SVM-p', 
    'non-linear svm (L)': 'r-SVM-p', 
    'logistic regression (L)': 'LogReg-p', 
    'rule_based_prediction': 'RuleBase'
}

model_name_list = list(model_name_dict.keys())

combined_dfs = [pd.concat(dfs, ignore_index=False) for dfs in result_dfs]
dfs_mean = [combined_df.groupby(combined_df.index).mean().reindex(index=model_name_list) for combined_df in combined_dfs]
dfs_std = [combined_df.groupby(combined_df.index).std().reindex(index=model_name_list) for combined_df in combined_dfs]

for df in dfs_mean:
    display(df)
# Out:
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816099
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.377612   0.34867  0.973913  0.507257   0.33535
# non-linear svm (L)          0.713433  0.541532   0.79646  0.639963  0.827856
# logistic regression (L)     0.767164  0.710831  0.496076  0.579919  0.823766
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     1.6    3.0            0.6
# non-linear svm (L)                 1.0    3.0           0.26
# logistic regression (L)            2.2    3.0           0.72
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               38.0                    68.8
# non-linear svm (L)                            5.6                    68.8
# logistic regression (L)                       8.2                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.480953
# non-linear svm (L)                          0.057846
# logistic regression (L)                     0.120951
# rule_based_prediction                            NaN
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816099
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.402985  0.370813  0.936364  0.512751  0.398896
# non-linear svm (L)          0.719403  0.555752    0.7548  0.632887  0.825338
# logistic regression (L)     0.767164  0.710831  0.496076  0.579919  0.823962
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     1.6    3.0            0.5
# non-linear svm (L)                 1.2    3.0           0.36
# logistic regression (L)            2.2    3.0           0.72
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               32.6                    68.8
# non-linear svm (L)                            5.8                    68.8
# logistic regression (L)                       8.2                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.382317
# non-linear svm (L)                          0.064768
# logistic regression (L)                     0.120951
# rule_based_prediction                            NaN
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816099
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.508955  0.401706  0.914819  0.553183  0.546588
# non-linear svm (L)          0.723881  0.555985   0.75976  0.639835  0.826895
# logistic regression (L)     0.768657  0.716496  0.496076  0.581533  0.825061
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     2.0    3.0           0.64
# non-linear svm (L)                 1.2    3.0           0.36
# logistic regression (L)            2.0    3.0           0.68
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               22.0                    68.8
# non-linear svm (L)                            5.4                    68.8
# logistic regression (L)                       8.0                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.254421
# non-linear svm (L)                          0.057221
# logistic regression (L)                     0.118951
# rule_based_prediction                            NaN
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816099
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.532836  0.421353   0.91657  0.569978  0.585095
# non-linear svm (L)          0.716418  0.554825  0.724292  0.619462  0.826404
# logistic regression (L)     0.771642  0.730175   0.48557  0.579359  0.826302
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     1.8    3.0           0.54
# non-linear svm (L)                 1.0    3.0           0.26
# logistic regression (L)            2.0    3.0           0.68
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               21.2                    68.8
# non-linear svm (L)                            5.2                    68.8
# logistic regression (L)                       8.0                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.231444
# non-linear svm (L)                           0.05562
# logistic regression (L)                     0.118951
# rule_based_prediction                            NaN
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.816099
# RuleFit Classifier (conti)  0.732836  0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.541791  0.422909  0.849202  0.554097  0.536379
# non-linear svm (L)          0.698507  0.530574  0.744953  0.610961  0.818925
# logistic regression (L)     0.776119  0.745987   0.48557   0.58367  0.830111
# rule_based_prediction            NaN       NaN       NaN       NaN       NaN
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     2.0    3.0           0.64
# non-linear svm (L)                 1.4    3.0            0.4
# logistic regression (L)            2.0    3.0           0.68
# rule_based_prediction              NaN    NaN            NaN
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.4                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               26.0                    68.8
# non-linear svm (L)                            6.2                    68.8
# logistic regression (L)                       7.8                    68.8
# rule_based_prediction                         NaN                     NaN
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.573755
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.294505
# non-linear svm (L)                          0.072711
# logistic regression (L)                      0.11846
# rule_based_prediction                            NaN

# %% [markdown]
# ## 実験結果の保存（クロスバリデーション）

# %%
import os
# 実験によってパラメータが違うので注意
######################################
######################################
######################################
######################################


for version, (dfs, info) in enumerate(zip(result_dfs, infos)):
    
    for nth_fold, df in enumerate(dfs):

        df['nth_fold'] = nth_fold
        df['n_splits'] = 5
        df['C1'] = 10
        df['C2'] = 10
        df['n_unsupervised'] = info
        df['rule_thr'] = 0.8

        # フォルダーを作成する
        ########################################
        ########################################
        ########################################
        ########################################
        ########################################
        folder_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/fold_{nth_fold}')
        os.makedirs(folder_path, exist_ok=True)

        file_path = f'{folder_path}/ver_{version}.csv'
        print(file_path)

        df.to_csv(file_path)
# Out:
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_0/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_1/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_2/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_3/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_4/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_0/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_1/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_2/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_3/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_4/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_0/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_1/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_2/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_3/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_4/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_0/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_1/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_2/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_3/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_4/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_0/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_1/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_2/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_3/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/fold_4/ver_4.csv

# %% [markdown]
# ## 実験結果の保存（クロスバリデーション，平均と標準偏差）

# %%
# 実験によってパラメータが違うので注意
######################################
######################################
######################################
######################################


for version, (info, df) in enumerate(zip(infos, dfs_mean)):
    df['C1'] = 10
    df['C2'] = 10
    df['n_unsupervised'] = info
    df['rule_thr'] = 0.8

    #####################################
    #####################################
    #####################################
    #####################################
    #####################################
    file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/ver_{version}_mean.csv')
    print(file_path)

    df.to_csv(file_path)

for version, (info, df) in enumerate(zip(infos, dfs_std)):
    df['C1'] = 10
    df['C2'] = 10
    df['n_unsupervised'] = info
    df['rule_thr'] = 0.8

    #####################################
    #####################################
    #####################################
    #####################################
    #####################################
    file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/ver_{version}_std.csv')
    print(file_path)

    df.to_csv(file_path)
# Out:
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/ver_0_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/ver_1_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/ver_2_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/ver_3_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/ver_4_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/ver_0_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/ver_1_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/ver_2_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/ver_3_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_14/ver_4_std.csv

# %% [markdown]
# ## ルールの整形と保存（csv）
#
# experiment_11, experiment_12, experiment_13，experiment_14 は無し．

# %%
# for nth_fold in range(5):
#     for version in range(len(infos)):

#         ###################################################
#         ###################################################
#         ###################################################
#         ###################################################
#         dir_path = os.path.join(project_dir_path, f"experiment_result/tmp/version_{expt_num}{version + 1}")

#         file_path_1 = f"{dir_path}/rules/rules_{nth_fold}.csv"
#         file_path_2 = f"{dir_path}/rules/rules_{nth_fold}.txt"
#         file_path_3 = f"{dir_path}/result.json"

#         with open(file_path_3, 'r') as f:
#             result = json.load(f)
#         rule_result = result['result'][f'fold_{nth_fold}']['rule_based_prediction']['violation_detail']
#         df_rule_result = pd.DataFrame(rule_result).T

        
#         df = pd.read_csv(file_path_1, index_col=0)

#         KB = []
#         with open(file_path_2, 'r') as f:
#             for line in f:
#                 KB.append(line.rstrip())

#         df.drop(['type', 'support', 'importance'], axis=1, inplace=True)
#         df['rule'] = KB[:df.shape[0]]

#         n_predicate_list = [] 
#         implication_bool_list = []
#         for h, rule in enumerate(df['rule']):
#             n_predicate_list.append(sum([1 for element in rule.split() if element not in ['⊗', '¬', '→']]))

#             # consequent カラムのために後で追加
#             if rule[rule.split().index('→') + 1] == '¬':
#                 implication_bool_list.append('¬')
#             else:
#                 implication_bool_list.append(None)

#         df['n_predicate'] = n_predicate_list
#         df['rank'] = df['coef'].apply(lambda x: sum(abs(x) > info for info in infos) - 1)


#         df['n_violation (instance)'] = df_rule_result[1].to_list()
#         df['n_evaluation (instance)'] = df_rule_result[0].to_list()
#         df['violation'] = df['n_violation (instance)'].apply(lambda x: 0 if x == 0 else 1)
#         df['consequent'] = implication_bool_list

#         display(df.head(3))
#         ########################################################
#         ########################################################
#         ########################################################
#         ########################################################
#         file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/fold_{nth_fold}/rules_{version}.csv')
#         df.to_csv(file_path)
