# %% [markdown]
# ## 一時保存した実験結果の読み込み

# %%
import json
import os

import sys
project_dir_path = "/Users/keisukeonoue/ws/lukasiewicz_2"
sys.path.append(project_dir_path)

import pandas as pd
import numpy as np

version_nums = [21, 22, 23, 24, 25, 26, 27]
expt_num = 2
expt_info_main = "c2"


# リスト内包表記を使用して複数のファイルパスを生成する
result_file_paths = [
    os.path.join(project_dir_path, f"experiment_result/tmp/version_{version_num}/result.json")
    for version_num in version_nums
]


result_dfs = []
infos = []

for path in result_file_paths:
    with open(path, 'r') as f:
        json_data = json.load(f)
    
    infos.append(json_data[expt_info_main])
    
    tmp = []

    for fold, _ in json_data['result'].items():
        result_df = pd.DataFrame(json_data['result'][fold]).T
        tmp.append(result_df)

    result_dfs.append(tmp)

model_name_dict = {
    'linear svm': 'l-SVM', 
    'non-linear svm': 'r-SVM', 
    'logistic regression': 'RogReg', 
    'RuleFit Classifier (disc)': 'RuleFit-d', 
    'RuleFit Classifier (conti)': 'RuleFit', 
    'tree generator (disc)': 'RF-d', 
    'tree generator (conti)': 'RF', 
    'linear svm (L)': 'l-SVM-p', 
    'non-linear svm (L)': 'r-SVM-p', 
    'logistic regression (L)': 'LogReg-p', 
}

model_name_list = list(model_name_dict.keys())

combined_dfs = [pd.concat(dfs, ignore_index=False) for dfs in result_dfs]
dfs_mean = [combined_df.groupby(combined_df.index).mean().reindex(index=model_name_list) for combined_df in combined_dfs]
dfs_std = [combined_df.groupby(combined_df.index).std().reindex(index=model_name_list) for combined_df in combined_dfs]

for df in dfs_mean:
    display(df)
# Out:
#                             accuracy  precision    recall        f1       auc  \
# linear svm                  0.779104   0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.759070  0.479714  0.587201  0.838064
# logistic regression         0.782090   0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582   0.742431  0.521271  0.610252  0.816100
# RuleFit Classifier (conti)  0.732836   0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791   0.627843  0.557706  0.582608  0.772322
# tree generator (conti)      0.782090   0.715158  0.568106  0.627460  0.832600
# linear svm (L)              0.631343   0.498162  0.784834  0.582834  0.799573
# non-linear svm (L)          0.698507   0.530161  0.795208  0.628374  0.827006
# logistic regression (L)     0.767164   0.710831  0.496076  0.579919  0.823640
#
#                             n_violation  n_rule  violation_rate
# linear svm                         32.0    36.2        0.885097
# non-linear svm                     33.0    36.2        0.911028
# logistic regression                32.2    36.2        0.890360
# RuleFit Classifier (disc)          29.6    36.2        0.810257
# RuleFit Classifier (conti)         32.0    36.2        0.885248
# tree generator (disc)              27.0    36.2        0.740900
# tree generator (conti)             32.0    36.2        0.883859
# linear svm (L)                     23.6    36.2        0.647132
# non-linear svm (L)                 24.2    36.2        0.667104
# logistic regression (L)            19.4    36.2        0.539522
#                             accuracy  precision    recall        f1       auc  \
# linear svm                  0.779104   0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.759070  0.479714  0.587201  0.838064
# logistic regression         0.782090   0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582   0.742431  0.521271  0.610252  0.816100
# RuleFit Classifier (conti)  0.732836   0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791   0.627843  0.557706  0.582608  0.772322
# tree generator (conti)      0.782090   0.715158  0.568106  0.627460  0.832600
# linear svm (L)              0.470149   0.402584  0.903461  0.536437  0.635845
# non-linear svm (L)          0.707463   0.537069  0.759470  0.624378  0.827610
# logistic regression (L)     0.767164   0.710831  0.496076  0.579919  0.824097
#
#                             n_violation  n_rule  violation_rate
# linear svm                         32.0    36.2        0.885097
# non-linear svm                     33.0    36.2        0.911028
# logistic regression                32.2    36.2        0.890360
# RuleFit Classifier (disc)          29.6    36.2        0.810257
# RuleFit Classifier (conti)         32.0    36.2        0.885248
# tree generator (disc)              27.0    36.2        0.740900
# tree generator (conti)             32.0    36.2        0.883859
# linear svm (L)                     23.0    36.2        0.631645
# non-linear svm (L)                 25.4    36.2        0.701394
# logistic regression (L)            19.4    36.2        0.539522
#                             accuracy  precision    recall        f1       auc  \
# linear svm                  0.779104   0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.759070  0.479714  0.587201  0.838064
# logistic regression         0.782090   0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582   0.742431  0.521271  0.610252  0.816100
# RuleFit Classifier (conti)  0.732836   0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791   0.627843  0.557706  0.582608  0.772322
# tree generator (conti)      0.782090   0.715158  0.568106  0.627460  0.832600
# linear svm (L)              0.479104   0.397354  0.941576  0.549351  0.481886
# non-linear svm (L)          0.704478   0.532092  0.774428  0.626195  0.825386
# logistic regression (L)     0.770149   0.719595  0.496076  0.583538  0.825235
#
#                             n_violation  n_rule  violation_rate
# linear svm                         32.0    36.2        0.885097
# non-linear svm                     33.0    36.2        0.911028
# logistic regression                32.2    36.2        0.890360
# RuleFit Classifier (disc)          29.6    36.2        0.810257
# RuleFit Classifier (conti)         32.0    36.2        0.885248
# tree generator (disc)              27.0    36.2        0.740900
# tree generator (conti)             32.0    36.2        0.883859
# linear svm (L)                     22.0    36.2        0.604559
# non-linear svm (L)                 26.2    36.2        0.722090
# logistic regression (L)            19.2    36.2        0.534259
#                             accuracy  precision    recall        f1       auc  \
# linear svm                  0.779104   0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.759070  0.479714  0.587201  0.838064
# logistic regression         0.782090   0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582   0.742431  0.521271  0.610252  0.816100
# RuleFit Classifier (conti)  0.732836   0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791   0.627843  0.557706  0.582608  0.772322
# tree generator (conti)      0.782090   0.715158  0.568106  0.627460  0.832600
# linear svm (L)              0.480597   0.394559  0.939773  0.549637  0.578527
# non-linear svm (L)          0.716418   0.543868  0.778800  0.639474  0.821866
# logistic regression (L)     0.770149   0.750699  0.447411  0.557743  0.828334
#
#                             n_violation  n_rule  violation_rate
# linear svm                         32.0    36.2        0.885097
# non-linear svm                     33.0    36.2        0.911028
# logistic regression                32.2    36.2        0.890360
# RuleFit Classifier (disc)          29.6    36.2        0.810257
# RuleFit Classifier (conti)         32.0    36.2        0.885248
# tree generator (disc)              27.0    36.2        0.740900
# tree generator (conti)             32.0    36.2        0.883859
# linear svm (L)                     23.6    36.2        0.648054
# non-linear svm (L)                 23.8    36.2        0.659097
# logistic regression (L)            20.0    36.2        0.553289
#                             accuracy  precision    recall        f1       auc  \
# linear svm                  0.779104   0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.759070  0.479714  0.587201  0.838064
# logistic regression         0.782090   0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582   0.742431  0.521271  0.610252  0.816100
# RuleFit Classifier (conti)  0.732836   0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791   0.627843  0.557706  0.582608  0.772322
# tree generator (conti)      0.782090   0.715158  0.568106  0.627460  0.832600
# linear svm (L)              0.453731   0.385522  0.869027  0.520601  0.566593
# non-linear svm (L)          0.719403   0.552062  0.727989  0.622738  0.809967
# logistic regression (L)     0.749254   0.762465  0.339577  0.461974  0.828797
#
#                             n_violation  n_rule  violation_rate
# linear svm                         32.0    36.2        0.885097
# non-linear svm                     33.0    36.2        0.911028
# logistic regression                32.2    36.2        0.890360
# RuleFit Classifier (disc)          29.6    36.2        0.810257
# RuleFit Classifier (conti)         32.0    36.2        0.885248
# tree generator (disc)              27.0    36.2        0.740900
# tree generator (conti)             32.0    36.2        0.883859
# linear svm (L)                     25.4    36.2        0.695245
# non-linear svm (L)                 25.8    36.2        0.717314
# logistic regression (L)            20.4    36.2        0.565452
#                             accuracy  precision    recall        f1       auc  \
# linear svm                  0.779104   0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.759070  0.479714  0.587201  0.838064
# logistic regression         0.782090   0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582   0.742431  0.521271  0.610252  0.816100
# RuleFit Classifier (conti)  0.732836   0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791   0.627843  0.557706  0.582608  0.772322
# tree generator (conti)      0.782090   0.715158  0.568106  0.627460  0.832600
# linear svm (L)              0.522388   0.432518  0.882265  0.559164  0.625898
# non-linear svm (L)          0.683582   0.540831  0.679050  0.581917  0.796534
# logistic regression (L)     0.734328   0.742909  0.296271  0.404921  0.825236
#
#                             n_violation  n_rule  violation_rate
# linear svm                         32.0    36.2        0.885097
# non-linear svm                     33.0    36.2        0.911028
# logistic regression                32.2    36.2        0.890360
# RuleFit Classifier (disc)          29.6    36.2        0.810257
# RuleFit Classifier (conti)         32.0    36.2        0.885248
# tree generator (disc)              27.0    36.2        0.740900
# tree generator (conti)             32.0    36.2        0.883859
# linear svm (L)                     24.0    36.2        0.657439
# non-linear svm (L)                 24.4    36.2        0.670799
# logistic regression (L)            21.2    36.2        0.586120
#                             accuracy  precision    recall        f1       auc  \
# linear svm                  0.779104   0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.759070  0.479714  0.587201  0.838064
# logistic regression         0.782090   0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582   0.742431  0.521271  0.610252  0.816100
# RuleFit Classifier (conti)  0.732836   0.601979  0.553471  0.571908  0.795116
# tree generator (disc)       0.741791   0.627843  0.557706  0.582608  0.772322
# tree generator (conti)      0.782090   0.715158  0.568106  0.627460  0.832600
# linear svm (L)              0.428358   0.375973  0.987500  0.541102  0.588898
# non-linear svm (L)          0.677612   0.515567  0.727839  0.591094  0.787524
# logistic regression (L)     0.694030   0.490000  0.102050  0.162952  0.809856
#
#                             n_violation  n_rule  violation_rate
# linear svm                         32.0    36.2        0.885097
# non-linear svm                     33.0    36.2        0.911028
# logistic regression                32.2    36.2        0.890360
# RuleFit Classifier (disc)          29.6    36.2        0.810257
# RuleFit Classifier (conti)         32.0    36.2        0.885248
# tree generator (disc)              27.0    36.2        0.740900
# tree generator (conti)             32.0    36.2        0.883859
# linear svm (L)                     21.4    36.2        0.589540
# non-linear svm (L)                 23.8    36.2        0.658381
# logistic regression (L)            16.8    36.2        0.465404

# %% [markdown]
# ## 実験結果の保存（クロスバリデーション）

# %%
import os
# 実験によってパラメータが違うので注意
######################################
######################################
######################################
######################################


for version, (dfs, info) in enumerate(zip(result_dfs, infos)):
    
    for nth_fold, df in enumerate(dfs):

        df['nth_fold'] = nth_fold
        df['n_splits'] = 5
        df['C1'] = 10
        df['C2'] = info
        df['n_unsupervised'] = 15
        df['rule_thr'] = 0.6

        # フォルダーを作成する
        ########################################
        ########################################
        ########################################
        ########################################
        ########################################
        folder_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/fold_{nth_fold}')
        os.makedirs(folder_path, exist_ok=True)

        file_path = f'{folder_path}/ver_{version}.csv'
        print(file_path)

        df.to_csv(file_path)
# Out:
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_0/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_1/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_2/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_3/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_4/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_0/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_1/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_2/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_3/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_4/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_0/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_1/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_2/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_3/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_4/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_0/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_1/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_2/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_3/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_4/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_0/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_1/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_2/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_3/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_4/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_0/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_1/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_2/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_3/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_4/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_0/ver_6.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_1/ver_6.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_2/ver_6.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_3/ver_6.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/fold_4/ver_6.csv

# %% [markdown]
# ## 実験結果の保存（クロスバリデーション，平均と標準偏差）

# %%
# 実験によってパラメータが違うので注意
######################################
######################################
######################################
######################################


for version, (info, df) in enumerate(zip(infos, dfs_mean)):
    df['C1'] = 10
    df['C2'] = info
    df['n_unsupervised'] = 15
    df['rule_thr'] = 0.6

    #####################################
    #####################################
    #####################################
    #####################################
    #####################################
    file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/ver_{version}_mean.csv')
    print(file_path)

    df.to_csv(file_path)

for version, (info, df) in enumerate(zip(infos, dfs_std)):
    df['C1'] = 10
    df['C2'] = info
    df['n_unsupervised'] = 15
    df['rule_thr'] = 0.6

    #####################################
    #####################################
    #####################################
    #####################################
    #####################################
    file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/ver_{version}_std.csv')
    print(file_path)

    df.to_csv(file_path)
# Out:
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_0_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_1_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_2_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_3_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_4_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_5_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_6_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_0_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_1_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_2_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_3_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_4_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_5_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_11/ver_6_std.csv

# %% [markdown]
# ## ルールの整形と保存（csv）
#
# experiment_11, experiment_12, experiment_13，experiment_14 は無し．

# %%
# for nth_fold in range(5):
#     for version in range(len(infos)):

#         ###################################################
#         ###################################################
#         ###################################################
#         ###################################################
#         dir_path = os.path.join(project_dir_path, f"experiment_result/tmp/version_{expt_num}{version + 1}")

#         file_path_1 = f"{dir_path}/rules/rules_{nth_fold}.csv"
#         file_path_2 = f"{dir_path}/rules/rules_{nth_fold}.txt"
#         file_path_3 = f"{dir_path}/result.json"

#         with open(file_path_3, 'r') as f:
#             result = json.load(f)
#         rule_result = result['result'][f'fold_{nth_fold}']['rule_based_prediction']['violation_detail']
#         df_rule_result = pd.DataFrame(rule_result).T

        
#         df = pd.read_csv(file_path_1, index_col=0)

#         KB = []
#         with open(file_path_2, 'r') as f:
#             for line in f:
#                 KB.append(line.rstrip())

#         df.drop(['type', 'support', 'importance'], axis=1, inplace=True)
#         df['rule'] = KB[:df.shape[0]]

#         n_predicate_list = [] 
#         implication_bool_list = []
#         for h, rule in enumerate(df['rule']):
#             n_predicate_list.append(sum([1 for element in rule.split() if element not in ['⊗', '¬', '→']]))

#             # consequent カラムのために後で追加
#             if rule[rule.split().index('→') + 1] == '¬':
#                 implication_bool_list.append('¬')
#             else:
#                 implication_bool_list.append(None)

#         df['n_predicate'] = n_predicate_list
#         df['rank'] = df['coef'].apply(lambda x: sum(abs(x) > info for info in infos) - 1)


#         df['n_violation (instance)'] = df_rule_result[1].to_list()
#         df['n_evaluation (instance)'] = df_rule_result[0].to_list()
#         df['violation'] = df['n_violation (instance)'].apply(lambda x: 0 if x == 0 else 1)
#         df['consequent'] = implication_bool_list

#         display(df.head(3))
#         ########################################################
#         ########################################################
#         ########################################################
#         ########################################################
#         file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_{expt_num}/fold_{nth_fold}/rules_{version}.csv')
#         df.to_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 16
#      14 with open(file_path_3, 'r') as f:
#      15     result = json.load(f)
# ---> 16 rule_result = result['result'][f'fold_{nth_fold}']['rule_based_prediction']['violation_detail']
#      17 df_rule_result = pd.DataFrame(rule_result).T
#      20 df = pd.read_csv(file_path_1, index_col=0)
#
# KeyError: 'rule_based_prediction'
