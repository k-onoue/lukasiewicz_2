# %% [markdown]
# ## 一時保存した実験結果の読み込み

# %%
import json
import os

import sys
project_dir_path = "/Users/keisukeonoue/ws/lukasiewicz_2"
sys.path.append(project_dir_path)

import pandas as pd
import numpy as np

version_nums = [101, 102, 103, 104, 105, 106]

# リスト内包表記を使用して複数のファイルパスを生成する
result_file_paths = [
    os.path.join(project_dir_path, f"experiment_result/tmp/version_{version_num}/result.json")
    for version_num in version_nums
]


result_dfs = []
infos = []

for path in result_file_paths:
    with open(path, 'r') as f:
        json_data = json.load(f)
    
    infos.append(json_data['rule_thr'])
    
    tmp = []

    for fold, _ in json_data['result'].items():
        result_df = pd.DataFrame(json_data['result'][fold]).T.drop(['violation_detail'], axis=1)
        tmp.append(result_df)

    result_dfs.append(tmp)

model_name_dict = {
    'linear svm': 'l-SVM', 
    'non-linear svm': 'r-SVM', 
    'logistic regression': 'RogReg', 
    'RuleFit Classifier (disc)': 'RuleFit-d', 
    'RuleFit Classifier (conti)': 'RuleFit', 
    'tree generator (disc)': 'RF-d', 
    'tree generator (conti)': 'RF', 
    'linear svm (L)': 'l-SVM-p', 
    'non-linear svm (L)': 'r-SVM-p', 
    'logistic regression (L)': 'LogReg-p', 
    'rule_based_prediction': 'RuleBase'
}

model_name_list = list(model_name_dict.keys())

combined_dfs = [pd.concat(dfs, ignore_index=False) for dfs in result_dfs]
dfs_mean = [combined_df.groupby(combined_df.index).mean().reindex(index=model_name_list) for combined_df in combined_dfs]
dfs_std = [combined_df.groupby(combined_df.index).std().reindex(index=model_name_list) for combined_df in combined_dfs]

for df in dfs_mean:
    display(df)
# Out:
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.815994
# RuleFit Classifier (conti)  0.738806  0.612505  0.556312  0.579261  0.797018
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.541791  0.434768  0.856103  0.559086  0.562332
# non-linear svm (L)           0.71791  0.547521  0.761836  0.635432  0.821875
# logistic regression (L)     0.770149  0.732412  0.470891  0.570208  0.826615
# rule_based_prediction       0.325373  0.325373       1.0  0.489178       0.5
#
#                            n_violation n_rule violation_rate  \
# linear svm                        31.4   36.0       0.874652
# non-linear svm                    32.4   36.0       0.900467
# logistic regression               31.6   36.0       0.879916
# RuleFit Classifier (disc)         29.0   36.0       0.798061
# RuleFit Classifier (conti)        31.6   36.0       0.880583
# tree generator (disc)             26.8   36.0       0.738482
# tree generator (conti)            31.4   36.0       0.873556
# linear svm (L)                    23.4   36.0       0.651444
# non-linear svm (L)                23.8   36.0       0.658986
# logistic regression (L)           19.6   36.0       0.549053
# rule_based_prediction             21.2   36.0       0.587035
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                  521.0                   590.6
# non-linear svm                              528.8                   590.6
# logistic regression                         523.6                   590.6
# RuleFit Classifier (disc)                   517.6                   590.6
# RuleFit Classifier (conti)                  519.4                   590.6
# tree generator (disc)                       507.6                   590.6
# tree generator (conti)                      523.0                   590.6
# linear svm (L)                              293.8                   590.6
# non-linear svm (L)                          150.8                   590.6
# logistic regression (L)                      95.4                   590.6
# rule_based_prediction                       474.0                   590.6
#
#                            violation_rate (instance)
# linear svm                                  0.881041
# non-linear svm                              0.894698
# logistic regression                          0.88567
# RuleFit Classifier (disc)                    0.87455
# RuleFit Classifier (conti)                  0.878731
# tree generator (disc)                       0.857428
# tree generator (conti)                      0.884506
# linear svm (L)                              0.474153
# non-linear svm (L)                          0.256131
# logistic regression (L)                     0.162218
# rule_based_prediction                       0.801546
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.815994
# RuleFit Classifier (conti)  0.738806  0.612505  0.556312  0.579261  0.797018
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.534328   0.42329  0.882062  0.559399  0.667946
# non-linear svm (L)          0.701493  0.530627  0.785606  0.627725  0.827467
# logistic regression (L)     0.776119  0.757705  0.470891  0.577723  0.825458
# rule_based_prediction       0.325373  0.325373       1.0  0.489178       0.5
#
#                            n_violation n_rule violation_rate  \
# linear svm                        16.2   18.2       0.892026
# non-linear svm                    16.6   18.2       0.913137
# logistic regression               16.4   18.2       0.903137
# RuleFit Classifier (disc)         14.2   18.2       0.777647
# RuleFit Classifier (conti)        16.4   18.2       0.904248
# tree generator (disc)             13.8   18.2       0.757647
# tree generator (conti)            16.0   18.2       0.880915
# linear svm (L)                    11.6   18.2       0.635882
# non-linear svm (L)                13.2   18.2        0.72366
# logistic regression (L)           10.0   18.2       0.552092
# rule_based_prediction             11.8   18.2       0.646993
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                  365.0                   403.0
# non-linear svm                              368.8                   403.0
# logistic regression                         366.8                   403.0
# RuleFit Classifier (disc)                   360.2                   403.0
# RuleFit Classifier (conti)                  366.6                   403.0
# tree generator (disc)                       361.0                   403.0
# tree generator (conti)                      366.8                   403.0
# linear svm (L)                              217.2                   403.0
# non-linear svm (L)                          111.2                   403.0
# logistic regression (L)                      46.4                   403.0
# rule_based_prediction                       354.6                   403.0
#
#                            violation_rate (instance)
# linear svm                                  0.897846
# non-linear svm                              0.907298
# logistic regression                         0.902507
# RuleFit Classifier (disc)                   0.883547
# RuleFit Classifier (conti)                  0.901585
# tree generator (disc)                       0.883918
# tree generator (conti)                      0.902848
# linear svm (L)                               0.52167
# non-linear svm (L)                          0.272393
# logistic regression (L)                     0.120501
# rule_based_prediction                       0.867613
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.815994
# RuleFit Classifier (conti)  0.738806  0.612505  0.556312  0.579261  0.797018
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.325373  0.325373       1.0  0.489178  0.348506
# non-linear svm (L)          0.714925  0.544039  0.759575  0.631353  0.827801
# logistic regression (L)     0.765672   0.71091  0.487739  0.573507  0.825165
# rule_based_prediction       0.325373  0.325373       1.0  0.489178       0.5
#
#                            n_violation n_rule violation_rate  \
# linear svm                         9.2   10.6       0.859615
# non-linear svm                     9.6   10.6       0.901282
# logistic regression                9.4   10.6       0.884615
# RuleFit Classifier (disc)          8.0   10.6       0.762179
# RuleFit Classifier (conti)        10.0   10.6           0.95
# tree generator (disc)              8.2   10.6       0.787179
# tree generator (conti)             9.6   10.6       0.909615
# linear svm (L)                     6.8   10.6       0.648077
# non-linear svm (L)                 6.4   10.6       0.605128
# logistic regression (L)            6.0   10.6       0.537179
# rule_based_prediction              6.8   10.6       0.648077
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                  170.6                   203.4
# non-linear svm                              174.0                   203.4
# logistic regression                         172.4                   203.4
# RuleFit Classifier (disc)                   167.2                   203.4
# RuleFit Classifier (conti)                  173.2                   203.4
# tree generator (disc)                       169.4                   203.4
# tree generator (conti)                      173.0                   203.4
# linear svm (L)                              164.0                   203.4
# non-linear svm (L)                           40.8                   203.4
# logistic regression (L)                      24.6                   203.4
# rule_based_prediction                       164.0                   203.4
#
#                            violation_rate (instance)
# linear svm                                  0.830717
# non-linear svm                              0.849608
# logistic regression                         0.840436
# RuleFit Classifier (disc)                   0.816573
# RuleFit Classifier (conti)                  0.847277
# tree generator (disc)                       0.825449
# tree generator (conti)                      0.842546
# linear svm (L)                              0.799575
# non-linear svm (L)                          0.190773
# logistic regression (L)                     0.113695
# rule_based_prediction                       0.799575
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.815994
# RuleFit Classifier (conti)  0.738806  0.612505  0.556312  0.579261  0.797018
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.410448  0.353204    0.9625  0.515872  0.554638
# non-linear svm (L)          0.725373  0.561531  0.738021  0.633911  0.826788
# logistic regression (L)     0.768657  0.716496  0.496076  0.581533  0.825359
# rule_based_prediction       0.325373  0.325373       1.0  0.489178       0.5
#
#                            n_violation n_rule violation_rate  \
# linear svm                         4.0    4.4       0.866667
# non-linear svm                     4.2    4.4       0.966667
# logistic regression                4.2    4.4       0.966667
# RuleFit Classifier (disc)          3.4    4.4       0.783333
# RuleFit Classifier (conti)         4.4    4.4            1.0
# tree generator (disc)              3.6    4.4       0.883333
# tree generator (conti)             4.2    4.4       0.966667
# linear svm (L)                     2.8    4.4          0.675
# non-linear svm (L)                 2.4    4.4           0.55
# logistic regression (L)            2.8    4.4       0.666667
# rule_based_prediction              2.6    4.4          0.575
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   67.8                    95.2
# non-linear svm                               70.8                    95.2
# logistic regression                          69.6                    95.2
# RuleFit Classifier (disc)                    65.8                    95.2
# RuleFit Classifier (conti)                   70.4                    95.2
# tree generator (disc)                        68.8                    95.2
# tree generator (conti)                       70.0                    95.2
# linear svm (L)                               59.0                    95.2
# non-linear svm (L)                           11.0                    95.2
# logistic regression (L)                      10.6                    95.2
# rule_based_prediction                        63.8                    95.2
#
#                            violation_rate (instance)
# linear svm                                  0.695724
# non-linear svm                              0.731554
# logistic regression                         0.716067
# RuleFit Classifier (disc)                   0.677642
# RuleFit Classifier (conti)                  0.727428
# tree generator (disc)                       0.715086
# tree generator (conti)                      0.721755
# linear svm (L)                              0.577074
# non-linear svm (L)                           0.10462
# logistic regression (L)                     0.108118
# rule_based_prediction                       0.659673
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.815994
# RuleFit Classifier (conti)  0.738806  0.612505  0.556312  0.579261  0.797018
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.508955  0.401706  0.914819  0.553183  0.546588
# non-linear svm (L)          0.723881  0.555985   0.75976  0.639835  0.826895
# logistic regression (L)     0.768657  0.716496  0.496076  0.581533  0.825061
# rule_based_prediction       0.325373  0.325373       1.0  0.489178       0.5
#
#                            n_violation n_rule violation_rate  \
# linear svm                         2.6    3.0           0.86
# non-linear svm                     2.8    3.0           0.96
# logistic regression                2.8    3.0           0.96
# RuleFit Classifier (disc)          2.2    3.0           0.78
# RuleFit Classifier (conti)         3.0    3.0            1.0
# tree generator (disc)              2.4    3.0           0.88
# tree generator (conti)             2.8    3.0           0.96
# linear svm (L)                     2.0    3.0           0.64
# non-linear svm (L)                 1.2    3.0           0.36
# logistic regression (L)            2.0    3.0           0.68
# rule_based_prediction              1.4    3.0            0.4
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   41.4                    68.8
# non-linear svm                               44.4                    68.8
# logistic regression                          43.2                    68.8
# RuleFit Classifier (disc)                    39.8                    68.8
# RuleFit Classifier (conti)                   44.2                    68.8
# tree generator (disc)                        42.8                    68.8
# tree generator (conti)                       43.6                    68.8
# linear svm (L)                               22.0                    68.8
# non-linear svm (L)                            5.4                    68.8
# logistic regression (L)                       8.0                    68.8
# rule_based_prediction                        37.8                    68.8
#
#                            violation_rate (instance)
# linear svm                                  0.520691
# non-linear svm                              0.573127
# logistic regression                         0.549155
# RuleFit Classifier (disc)                   0.500069
# RuleFit Classifier (conti)                  0.570246
# tree generator (disc)                       0.586544
# tree generator (conti)                      0.567118
# linear svm (L)                              0.254421
# non-linear svm (L)                          0.057221
# logistic regression (L)                     0.118951
# rule_based_prediction                       0.473545
#                             accuracy precision    recall        f1       auc  \
# linear svm                  0.779104  0.711436  0.551175  0.618693  0.837805
# non-linear svm              0.780597   0.75907  0.479714  0.587201  0.838064
# logistic regression          0.78209  0.731143  0.530165  0.612464  0.840573
# RuleFit Classifier (disc)   0.783582  0.742431  0.521271  0.610252  0.815994
# RuleFit Classifier (conti)  0.738806  0.612505  0.556312  0.579261  0.797018
# tree generator (disc)       0.741791  0.627843  0.557706  0.582608  0.772322
# tree generator (conti)       0.78209  0.715158  0.568106   0.62746    0.8326
# linear svm (L)              0.467164  0.383173  0.935227  0.538908  0.470436
# non-linear svm (L)           0.71791  0.547063  0.764015   0.63569  0.826937
# logistic regression (L)     0.768657  0.716496  0.496076  0.581533  0.824521
# rule_based_prediction       0.325373  0.325373       1.0  0.489178       0.5
#
#                            n_violation n_rule violation_rate  \
# linear svm                         1.8    2.0            0.9
# non-linear svm                     2.0    2.0            1.0
# logistic regression                2.0    2.0            1.0
# RuleFit Classifier (disc)          1.6    2.0       0.833333
# RuleFit Classifier (conti)         2.0    2.0            1.0
# tree generator (disc)              1.8    2.0       0.933333
# tree generator (conti)             2.0    2.0            1.0
# linear svm (L)                     1.2    2.0       0.566667
# non-linear svm (L)                 0.8    2.0       0.366667
# logistic regression (L)            1.2    2.0       0.633333
# rule_based_prediction              0.8    2.0       0.366667
#
#                            n_violation (instance) n_evaluation (instance)  \
# linear svm                                   24.4                    50.4
# non-linear svm                               27.4                    50.4
# logistic regression                          26.2                    50.4
# RuleFit Classifier (disc)                    23.2                    50.4
# RuleFit Classifier (conti)                   27.0                    50.4
# tree generator (disc)                        26.2                    50.4
# tree generator (conti)                       26.6                    50.4
# linear svm (L)                               13.0                    50.4
# non-linear svm (L)                            1.2                    50.4
# logistic regression (L)                       5.4                    50.4
# rule_based_prediction                        21.2                    50.4
#
#                            violation_rate (instance)
# linear svm                                  0.443561
# non-linear svm                              0.507526
# logistic regression                         0.481632
# RuleFit Classifier (disc)                   0.421325
# RuleFit Classifier (conti)                  0.495755
# tree generator (disc)                       0.509722
# tree generator (conti)                      0.496418
# linear svm (L)                              0.233329
# non-linear svm (L)                          0.021759
# logistic regression (L)                     0.118359
# rule_based_prediction                       0.381426

# %% [markdown]
# ## 実験結果の保存（クロスバリデーション）

# %%
import os

for version, (dfs, info) in enumerate(zip(result_dfs, infos)):
    
    for nth_fold, df in enumerate(dfs):

        df['nth_fold'] = nth_fold
        df['n_splits'] = 5
        df['C1'] = 10
        df['C2'] = 10
        df['n_unsupervised'] = 15
        df['rule_thr'] = info

        # フォルダーを作成する
        ########################################
        ########################################
        ########################################
        ########################################
        ########################################
        folder_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_10/fold_{nth_fold}')
        os.makedirs(folder_path, exist_ok=True)

        file_path = f'{folder_path}/ver_{version}.csv'
        print(file_path)

        df.to_csv(file_path)
# Out:
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_0/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_1/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_2/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_3/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_4/ver_0.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_0/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_1/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_2/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_3/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_4/ver_1.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_0/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_1/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_2/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_3/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_4/ver_2.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_0/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_1/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_2/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_3/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_4/ver_3.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_0/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_1/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_2/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_3/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_4/ver_4.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_0/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_1/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_2/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_3/ver_5.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/fold_4/ver_5.csv

# %% [markdown]
# ## 実験結果の保存（クロスバリデーション，平均と標準偏差）

# %%
for version, (info, df) in enumerate(zip(infos, dfs_mean)):
    df['C1'] = 10
    df['C2'] = 10
    df['n_unsupervised'] = 15
    df['rule_thr'] = info

    #####################################
    #####################################
    #####################################
    #####################################
    #####################################
    file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_10/ver_{version}_mean.csv')
    print(file_path)

    df.to_csv(file_path)

for version, (info, df) in enumerate(zip(infos, dfs_std)):
    df['C1'] = 10
    df['C2'] = 10
    df['n_unsupervised'] = 15
    df['rule_thr'] = info

    #####################################
    #####################################
    #####################################
    #####################################
    #####################################
    file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_10/ver_{version}_std.csv')
    print(file_path)

    df.to_csv(file_path)
# Out:
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_0_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_1_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_2_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_3_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_4_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_5_mean.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_0_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_1_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_2_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_3_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_4_std.csv
# /Users/keisukeonoue/ws/lukasiewicz_2/experiment_result/results_organized/experiment_10/ver_5_std.csv

# %% [markdown]
# ## ルールの整形と保存（csv）

# %%
for nth_fold in range(5):
    for version in range(len(infos)):

        ###################################################
        ###################################################
        ###################################################
        ###################################################
        dir_path = os.path.join(project_dir_path, f"experiment_result/tmp/version_10{version + 1}")

        file_path_1 = f"{dir_path}/rules/rules_{nth_fold}.csv"
        file_path_2 = f"{dir_path}/rules/rules_{nth_fold}.txt"
        file_path_3 = f"{dir_path}/result.json"

        with open(file_path_3, 'r') as f:
            result = json.load(f)
        rule_result = result['result'][f'fold_{nth_fold}']['rule_based_prediction']['violation_detail']
        df_rule_result = pd.DataFrame(rule_result).T

        
        df = pd.read_csv(file_path_1, index_col=0)

        KB = []
        with open(file_path_2, 'r') as f:
            for line in f:
                KB.append(line.rstrip())

        df.drop(['type', 'support', 'importance'], axis=1, inplace=True)
        df['rule'] = KB[:df.shape[0]]

        n_predicate_list = [] 
        implication_bool_list = []
        for h, rule in enumerate(df['rule']):
            n_predicate_list.append(sum([1 for element in rule.split() if element not in ['⊗', '¬', '→']]))

            # consequent カラムのために後で追加
            if rule[rule.split().index('→') + 1] == '¬':
                implication_bool_list.append('¬')
            else:
                implication_bool_list.append(None)

        df['n_predicate'] = n_predicate_list
        df['rank'] = df['coef'].apply(lambda x: sum(abs(x) > info for info in infos) - 1)


        df['n_violation (instance)'] = df_rule_result[1].to_list()
        df['n_evaluation (instance)'] = df_rule_result[0].to_list()
        df['violation'] = df['n_violation (instance)'].apply(lambda x: 0 if x == 0 else 1)
        df['consequent'] = implication_bool_list

        display(df.head(3))
        ########################################################
        ########################################################
        ########################################################
        ########################################################
        file_path = os.path.join(project_dir_path, f'experiment_result/results_organized/experiment_10/fold_{nth_fold}/rules_{version}.csv')
        df.to_csv(file_path)
# Out:
#                           rule      coef  n_predicate  rank  \
# 0  Pregnancies_Low → ¬ Outcome -0.353076            2     1
# 3      Glucose_Low → ¬ Outcome -1.237307            2     5
# 5       Glucose_High → Outcome  1.367137            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 0                      79                       79          1       None
# 3                      31                       31          1       None
# 5                       0                       26          0       None
#                           rule      coef  n_predicate  rank  \
# 0  Pregnancies_Low → ¬ Outcome -0.353076            2     1
# 3      Glucose_Low → ¬ Outcome -1.237307            2     5
# 5       Glucose_High → Outcome  1.367137            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 0                      79                       79          1       None
# 3                      31                       31          1       None
# 5                       0                       26          0       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.237307            2     5
# 5    Glucose_High → Outcome  1.367137            2     5
# 12      BMI_Low → ¬ Outcome -0.664089            2     3
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       31                       31          1       None
# 5                        0                       26          0       None
# 12                      45                       45          1       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.237307            2     5
# 5    Glucose_High → Outcome  1.367137            2     5
# 12      BMI_Low → ¬ Outcome -0.664089            2     3
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       31                       31          1       None
# 5                        0                       26          0       None
# 12                      45                       45          1       None
#                       rule      coef  n_predicate  rank  \
# 3  Glucose_Low → ¬ Outcome -1.237307            2     5
# 5   Glucose_High → Outcome  1.367137            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                      31                       31          1       None
# 5                       0                       26          0       None
#                       rule      coef  n_predicate  rank  \
# 3  Glucose_Low → ¬ Outcome -1.237307            2     5
# 5   Glucose_High → Outcome  1.367137            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                      31                       31          1       None
# 5                       0                       26          0       None
#                           rule      coef  n_predicate  rank  \
# 0  Pregnancies_Low → ¬ Outcome -0.058192            2     0
# 3      Glucose_Low → ¬ Outcome -1.304996            2     5
# 5       Glucose_High → Outcome  1.130443            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 0                      81                       81          1       None
# 3                      21                       21          1       None
# 5                       0                       30          0       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.304996            2     5
# 5    Glucose_High → Outcome  1.130443            2     5
# 12      BMI_Low → ¬ Outcome -0.931496            2     4
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       21                       21          1       None
# 5                        0                       30          0       None
# 12                      40                       40          1       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.304996            2     5
# 5    Glucose_High → Outcome  1.130443            2     5
# 12      BMI_Low → ¬ Outcome -0.931496            2     4
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       21                       21          1       None
# 5                        0                       30          0       None
# 12                      40                       40          1       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.304996            2     5
# 5    Glucose_High → Outcome  1.130443            2     5
# 12      BMI_Low → ¬ Outcome -0.931496            2     4
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       21                       21          1       None
# 5                        0                       30          0       None
# 12                      40                       40          1       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.304996            2     5
# 5    Glucose_High → Outcome  1.130443            2     5
# 12      BMI_Low → ¬ Outcome -0.931496            2     4
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       21                       21          1       None
# 5                        0                       30          0       None
# 12                      40                       40          1       None
#                                                     rule      coef  \
# 3                                Glucose_Low → ¬ Outcome -1.304996
# 5                                 Glucose_High → Outcome  1.130443
# 10909  ¬ BMI_Low ⊗ ¬ Glucose_Low ⊗ ¬ Glucose_Medium ⊗...  1.171933
#
#        n_predicate  rank  n_violation (instance)  n_evaluation (instance)  \
# 3                2     5                      21                       21
# 5                2     5                       0                       30
# 10909            6     5                       0                       13
#
#        violation consequent
# 3              1       None
# 5              0       None
# 10909          0       None
#                           rule      coef  n_predicate  rank  \
# 0  Pregnancies_Low → ¬ Outcome -0.351179            2     1
# 2   Pregnancies_High → Outcome  0.146773            2     0
# 3      Glucose_Low → ¬ Outcome -0.475201            2     2
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 0                      94                       94          1       None
# 2                       0                       12          0       None
# 3                      31                       31          1       None
#                           rule      coef  n_predicate  rank  \
# 0  Pregnancies_Low → ¬ Outcome -0.351179            2     1
# 3      Glucose_Low → ¬ Outcome -0.475201            2     2
# 5       Glucose_High → Outcome  1.280784            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 0                      94                       94          1       None
# 3                      31                       31          1       None
# 5                       0                       27          0       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -0.475201            2     2
# 5    Glucose_High → Outcome  1.280784            2     5
# 12      BMI_Low → ¬ Outcome -0.627466            2     3
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       31                       31          1       None
# 5                        0                       27          0       None
# 12                      45                       45          1       None
#                       rule      coef  n_predicate  rank  \
# 5   Glucose_High → Outcome  1.280784            2     5
# 12     BMI_Low → ¬ Outcome -0.627466            2     3
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 5                        0                       27          0       None
# 12                      45                       45          1       None
#                      rule      coef  n_predicate  rank  \
# 5  Glucose_High → Outcome  1.280784            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 5                       0                       27          0       None
#                      rule      coef  n_predicate  rank  \
# 5  Glucose_High → Outcome  1.280784            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 5                       0                       27          0       None
#                           rule      coef  n_predicate  rank  \
# 0  Pregnancies_Low → ¬ Outcome -0.271941            2     1
# 3      Glucose_Low → ¬ Outcome -1.392655            2     5
# 5       Glucose_High → Outcome  1.333939            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 0                      89                       89          1       None
# 3                      32                       32          1       None
# 5                       0                       21          0       None
#                           rule      coef  n_predicate  rank  \
# 0  Pregnancies_Low → ¬ Outcome -0.271941            2     1
# 3      Glucose_Low → ¬ Outcome -1.392655            2     5
# 5       Glucose_High → Outcome  1.333939            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 0                      89                       89          1       None
# 3                      32                       32          1       None
# 5                       0                       21          0       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.392655            2     5
# 5    Glucose_High → Outcome  1.333939            2     5
# 12      BMI_Low → ¬ Outcome -0.584939            2     2
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       32                       32          1       None
# 5                        0                       21          0       None
# 12                      44                       44          1       None
#                       rule      coef  n_predicate  rank  \
# 3  Glucose_Low → ¬ Outcome -1.392655            2     5
# 5   Glucose_High → Outcome  1.333939            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                      32                       32          1       None
# 5                       0                       21          0       None
#                       rule      coef  n_predicate  rank  \
# 3  Glucose_Low → ¬ Outcome -1.392655            2     5
# 5   Glucose_High → Outcome  1.333939            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                      32                       32          1       None
# 5                       0                       21          0       None
#                       rule      coef  n_predicate  rank  \
# 3  Glucose_Low → ¬ Outcome -1.392655            2     5
# 5   Glucose_High → Outcome  1.333939            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                      32                       32          1       None
# 5                       0                       21          0       None
#                           rule      coef  n_predicate  rank  \
# 0  Pregnancies_Low → ¬ Outcome -0.164023            2     0
# 3      Glucose_Low → ¬ Outcome -1.091643            2     5
# 5       Glucose_High → Outcome  1.217328            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 0                      87                       87          1       None
# 3                      22                       22          1       None
# 5                       0                       29          0       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.091643            2     5
# 5    Glucose_High → Outcome  1.217328            2     5
# 12      BMI_Low → ¬ Outcome -0.989185            2     4
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       22                       22          1       None
# 5                        0                       29          0       None
# 12                      40                       40          1       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.091643            2     5
# 5    Glucose_High → Outcome  1.217328            2     5
# 12      BMI_Low → ¬ Outcome -0.989185            2     4
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       22                       22          1       None
# 5                        0                       29          0       None
# 12                      40                       40          1       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.091643            2     5
# 5    Glucose_High → Outcome  1.217328            2     5
# 12      BMI_Low → ¬ Outcome -0.989185            2     4
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       22                       22          1       None
# 5                        0                       29          0       None
# 12                      40                       40          1       None
#                        rule      coef  n_predicate  rank  \
# 3   Glucose_Low → ¬ Outcome -1.091643            2     5
# 5    Glucose_High → Outcome  1.217328            2     5
# 12      BMI_Low → ¬ Outcome -0.989185            2     4
#
#     n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                       22                       22          1       None
# 5                        0                       29          0       None
# 12                      40                       40          1       None
#                       rule      coef  n_predicate  rank  \
# 3  Glucose_Low → ¬ Outcome -1.091643            2     5
# 5   Glucose_High → Outcome  1.217328            2     5
#
#    n_violation (instance)  n_evaluation (instance)  violation consequent
# 3                      22                       22          1       None
# 5                       0                       29          0       None
