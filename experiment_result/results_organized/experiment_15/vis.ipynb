# %% [markdown]
# - 医療検査においては，recall が高いと良い．（取りこぼしが無いという意味で）
# -
#
# ルールの多数決による予測は，recall が 1．l-svm-p, r-svm-p (提案モデル) は l-svm，r-svm (ベンチマークモデル) より高かった．しかし LogReg-p は LogReg よりも低かった．

# %%
import os

file_name_list = sorted([df_name for df_name in os.listdir() if "mean" in df_name])
file_name_list
# Out:
# ['ver_0_mean.csv',
#  'ver_1_mean.csv',
#  'ver_2_mean.csv',
#  'ver_3_mean.csv',
#  'ver_4_mean.csv',
#  'ver_5_mean.csv',
#  'ver_6_mean.csv',
#  'ver_7_mean.csv']

# %%
model_name_dict = {
    'linear svm': 'l-SVM', 
    'non-linear svm': 'r-SVM', 
    'logistic regression': 'LogReg', 
    'RuleFit Classifier (disc)': 'RuleFit-d', 
    'RuleFit Classifier (conti)': 'RuleFit', 
    'tree generator (disc)': 'RF-d', 
    'tree generator (conti)': 'RF', 
    'linear svm (L)': 'l-SVM-p', 
    'non-linear svm (L)': 'r-SVM-p', 
    'logistic regression (L)': 'LogReg-p', 
    'rule_based_prediction': 'RuleBase'
}

# %%
import pandas as pd

df_list = [pd.read_csv(df_name, index_col=0).T.rename(columns=model_name_dict) for df_name in file_name_list]
df_list[0]
# Out:
#                              RuleFit-d         RF-d      RuleFit           RF  \
# accuracy                      0.783582     0.741791     0.732836     0.782090
# precision                     0.742431     0.627843     0.601979     0.715158
# recall                        0.521271     0.557706     0.553471     0.568106
# f1                            0.610252     0.582608     0.571908     0.627460
# auc                           0.815651     0.772322     0.795116     0.832600
# n_violation                  45.400000    46.000000    46.000000    45.800000
# n_rule                       46.000000    46.000000    46.000000    46.000000
# violation_rate                0.988235     1.000000     1.000000     0.996078
# n_violation (instance)     2734.600000  2634.200000  2632.800000  2702.400000
# n_evaluation (instance)    3148.000000  3148.000000  3148.000000  3148.000000
# violation_rate (instance)     0.869052     0.837924     0.836848     0.858960
# C1                           10.000000    10.000000    10.000000    10.000000
# C2                           10.000000    10.000000    10.000000    10.000000
# n_unsupervised               15.000000    15.000000    15.000000    15.000000
# rule_thr                      0.000000     0.000000     0.000000     0.000000
#
#                                  l-SVM        r-SVM       LogReg      l-SVM-p  \
# accuracy                      0.779104     0.780597     0.782090     0.617910
# precision                     0.711436     0.759070     0.731143     0.471546
# recall                        0.551175     0.479714     0.530165     0.883547
# f1                            0.618693     0.587201     0.612464     0.608462
# auc                           0.837805     0.838064     0.840573     0.680065
# n_violation                  45.400000    46.000000    46.000000    43.000000
# n_rule                       46.000000    46.000000    46.000000    46.000000
# violation_rate                0.988235     1.000000     1.000000     0.926789
# n_violation (instance)     2726.400000  2803.400000  2759.600000  1408.600000
# n_evaluation (instance)    3148.000000  3148.000000  3148.000000  3148.000000
# violation_rate (instance)     0.866152     0.889837     0.876497     0.450271
# C1                           10.000000    10.000000    10.000000    10.000000
# C2                           10.000000    10.000000    10.000000    10.000000
# n_unsupervised               15.000000    15.000000    15.000000    15.000000
# rule_thr                      0.000000     0.000000     0.000000     0.000000
#
#                                r-SVM-p     LogReg-p     RuleBase
# accuracy                      0.683582     0.738806     0.325373
# precision                     0.525018     0.766883     0.325373
# recall                        0.756815     0.291550     1.000000
# f1                            0.607215     0.416785     0.489178
# auc                           0.795545     0.827454     0.500000
# n_violation                  44.600000    45.800000    21.200000
# n_rule                       46.000000    46.000000    46.000000
# violation_rate                0.970228     0.995833     0.461741
# n_violation (instance)     1398.200000  1478.000000  1573.400000
# n_evaluation (instance)    3148.000000  3148.000000  3148.000000
# violation_rate (instance)     0.443859     0.469113     0.500551
# C1                           10.000000    10.000000    10.000000
# C2                           10.000000    10.000000    10.000000
# n_unsupervised               15.000000    15.000000    15.000000
# rule_thr                      0.000000     0.000000     0.000000

# %%
def get_table(df_list, model_name_list, metrics, index=None):
    print(metrics)
    table = pd.DataFrame()
    for i, df in enumerate(df_list):
        table[i] = df.loc[metrics, model_name_list]
    table = table.T
    if index is not None:
        table.index = index
    return table

index = [df.loc['rule_thr', 'RuleBase'] for df in df_list]
df = get_table(df_list, model_name_dict.values(), 'accuracy', index=index)
df
# Out:
# accuracy
#         l-SVM     r-SVM   LogReg  RuleFit-d   RuleFit      RF-d       RF  \
# 0.0  0.779104  0.780597  0.78209   0.783582  0.732836  0.741791  0.78209
# 0.1  0.779104  0.780597  0.78209   0.783582  0.732836  0.741791  0.78209
# 0.2  0.779104  0.780597  0.78209   0.783582  0.732836  0.741791  0.78209
# 0.3  0.779104  0.780597  0.78209   0.783582  0.732836  0.741791  0.78209
# 0.4  0.779104  0.780597  0.78209   0.783582  0.732836  0.741791  0.78209
# 0.5  0.779104  0.780597  0.78209   0.783582  0.732836  0.741791  0.78209
# 0.6  0.779104  0.780597  0.78209   0.783582  0.732836  0.741791  0.78209
# 0.7  0.779104  0.780597  0.78209   0.783582  0.732836  0.741791  0.78209
#
#       l-SVM-p   r-SVM-p  LogReg-p  RuleBase
# 0.0  0.617910  0.683582  0.738806  0.325373
# 0.1  0.617910  0.683582  0.738806  0.325373
# 0.2  0.616418  0.708955  0.732836  0.325373
# 0.3  0.540299  0.732836  0.728358  0.325373
# 0.4  0.389552  0.707463  0.761194  0.325373
# 0.5  0.325373  0.720896  0.765672  0.325373
# 0.6  0.462687  0.702985  0.777612  0.325373
# 0.7  0.434328  0.704478  0.765672  0.325373

# %%
index = [df.loc['rule_thr', 'RuleBase'] for df in df_list]
metrics = ['accuracy', 'precision', 'recall', 'f1', 'auc', 'violation_rate', 'violation_rate (instance)']
df_table_list = [get_table(df_list, model_name_dict.values(), metric, index=index) for metric in metrics]
tmp_list = [(df, metrics) for df, metrics in zip(df_table_list, metrics)]


csv_file = 'vis_table.csv'

# CSVにデータを保存
with open(csv_file, 'w') as f:
    for df, metric in tmp_list:
        # メトリクスを書き込む
        f.write(f'{metric}\n')
        # データフレームをCSVに書き込む
        df.to_csv(f)
        # メトリクスとデータフレームの間に空行を挿入
        f.write('\n')
# Out:
# accuracy
# precision
# recall
# f1
# auc
# violation_rate
# violation_rate (instance)

# %%
import os
import pandas as pd

csv_file = 'vis_table_b.csv'


file_name_list = sorted([df_name for df_name in os.listdir() if "mean" in df_name])
print(file_name_list)

model_name_dict = {
    'linear svm': 'l-SVM', 
    'non-linear svm': 'r-SVM', 
    'logistic regression': 'LogReg', 
    'RuleFit Classifier (disc)': 'RuleFit-d', 
    'RuleFit Classifier (conti)': 'RuleFit', 
    'tree generator (disc)': 'RF-d', 
    'tree generator (conti)': 'RF', 
    'rule_based_prediction': 'RuleBase'
}

df_list = [pd.read_csv(df_name, index_col=0).T.rename(columns=model_name_dict) for df_name in file_name_list]

def get_table(df_list, model_name_list, metrics, index=None):
    print(metrics)
    table = pd.DataFrame()
    for i, df in enumerate(df_list):
        table[i] = df.loc[metrics, model_name_list]
    table = table.T
    if index is not None:
        table.index = index
    return table

index = [df.loc['rule_thr', 'RuleBase'] for df in df_list]
metrics = ['accuracy', 'precision', 'recall', 'f1', 'auc', 'violation_rate', 'violation_rate (instance)']
df_table_list = [get_table(df_list, model_name_dict.values(), metric, index=index) for metric in metrics]
tmp_list = [(df, metrics) for df, metrics in zip(df_table_list, metrics)]


# CSVにデータを保存
with open(csv_file, 'w') as f:
    for df, metric in tmp_list:
        # メトリクスを書き込む
        f.write(f'{metric}\n')
        # データフレームをCSVに書き込む
        df.to_csv(f)
        # メトリクスとデータフレームの間に空行を挿入
        f.write('\n')
# Out:
# ['ver_0_mean.csv', 'ver_1_mean.csv', 'ver_2_mean.csv', 'ver_3_mean.csv', 'ver_4_mean.csv', 'ver_5_mean.csv', 'ver_6_mean.csv', 'ver_7_mean.csv']
# accuracy
# precision
# recall
# f1
# auc
# violation_rate
# violation_rate (instance)

# %%
import os
import pandas as pd

csv_file = 'vis_table_p.csv'


file_name_list = sorted([df_name for df_name in os.listdir() if "mean" in df_name])
print(file_name_list)

model_name_dict = {
    'linear svm (L)': 'l-SVM-p', 
    'non-linear svm (L)': 'r-SVM-p', 
    'logistic regression (L)': 'LogReg-p', 
}

df_list = [pd.read_csv(df_name, index_col=0).T.rename(columns=model_name_dict) for df_name in file_name_list]

def get_table(df_list, model_name_list, metrics, index=None):
    print(metrics)
    table = pd.DataFrame()
    for i, df in enumerate(df_list):
        table[i] = df.loc[metrics, model_name_list]
    table = table.T
    if index is not None:
        table.index = index
    return table

index = [df.loc['rule_thr'][0] for df in df_list]
metrics = ['accuracy', 'precision', 'recall', 'f1', 'auc', 'violation_rate', 'violation_rate (instance)']
df_table_list = [get_table(df_list, model_name_dict.values(), metric, index=index) for metric in metrics]
tmp_list = [(df, metrics) for df, metrics in zip(df_table_list, metrics)]


# CSVにデータを保存
with open(csv_file, 'w') as f:
    for df, metric in tmp_list:
        # メトリクスを書き込む
        f.write(f'{metric}\n')
        # データフレームをCSVに書き込む
        df.to_csv(f)
        # メトリクスとデータフレームの間に空行を挿入
        f.write('\n')
# Out:
# ['ver_0_mean.csv', 'ver_1_mean.csv', 'ver_2_mean.csv', 'ver_3_mean.csv', 'ver_4_mean.csv', 'ver_5_mean.csv', 'ver_6_mean.csv', 'ver_7_mean.csv']
# accuracy
# precision
# recall
# f1
# auc
# violation_rate
# violation_rate (instance)
# /var/folders/_b/b62kq0490fn2ptq7m4mbp8yr0000gp/T/ipykernel_43342/1725615649.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   index = [df.loc['rule_thr'][0] for df in df_list]
